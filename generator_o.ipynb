# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/ai-creator-archive/blob/main/generator_o.ipynb)

# %%
# https://github.com/kjsman/stable-diffusion-pytorch/issues/7#issuecomment-1426839447 modified thanks to @treeform ❤

# %cd /content
# !git clone -b dev https://github.com/camenduru/stable-diffusion-pytorch

# %cd /content/stable-diffusion-pytorch
# %pip install piexif fold_to_ascii discord ftfy safetensors -r requirements.txt

# !apt -y install -qq aria2
ckpt = "https://huggingface.co/ckpt/mouseymix/resolve/main/mouseymix.safetensors" #@param { type: "string" }
# !rm /content/model
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M {ckpt} -d /content -o model

# !mkdir /content/stable-diffusion-pytorch/data/ckpt

import torch, gc
from safetensors.torch import save_file, load_file

if 'models' in globals():  
  del models
with torch.no_grad():
  torch.cuda.empty_cache()
gc.collect()

old = load_file("/content/model")
# old = torch.load("/content/model", weights_only = False, map_location=torch.device('cuda'))["state_dict"]
# old = torch.load("/content/model", weights_only = False, map_location=torch.device('cuda'))

new = {}
new['diffusion'] = {}
new['encoder'] = {}
new['decoder'] = {}
new['clip'] = {}

new['diffusion']['time_embedding.linear_1.weight'] = old['model.diffusion_model.time_embed.0.weight']
new['diffusion']['time_embedding.linear_1.bias'] = old['model.diffusion_model.time_embed.0.bias']
new['diffusion']['time_embedding.linear_2.weight'] = old['model.diffusion_model.time_embed.2.weight']
new['diffusion']['time_embedding.linear_2.bias'] = old['model.diffusion_model.time_embed.2.bias']
new['diffusion']['unet.encoders.0.0.weight'] = old['model.diffusion_model.input_blocks.0.0.weight']
new['diffusion']['unet.encoders.0.0.bias'] = old['model.diffusion_model.input_blocks.0.0.bias']
new['diffusion']['unet.encoders.1.0.groupnorm_feature.weight'] = old['model.diffusion_model.input_blocks.1.0.in_layers.0.weight']
new['diffusion']['unet.encoders.1.0.groupnorm_feature.bias'] = old['model.diffusion_model.input_blocks.1.0.in_layers.0.bias']
new['diffusion']['unet.encoders.1.0.conv_feature.weight'] = old['model.diffusion_model.input_blocks.1.0.in_layers.2.weight']
new['diffusion']['unet.encoders.1.0.conv_feature.bias'] = old['model.diffusion_model.input_blocks.1.0.in_layers.2.bias']
new['diffusion']['unet.encoders.1.0.linear_time.weight'] = old['model.diffusion_model.input_blocks.1.0.emb_layers.1.weight']
new['diffusion']['unet.encoders.1.0.linear_time.bias'] = old['model.diffusion_model.input_blocks.1.0.emb_layers.1.bias']
new['diffusion']['unet.encoders.1.0.groupnorm_merged.weight'] = old['model.diffusion_model.input_blocks.1.0.out_layers.0.weight']
new['diffusion']['unet.encoders.1.0.groupnorm_merged.bias'] = old['model.diffusion_model.input_blocks.1.0.out_layers.0.bias']
new['diffusion']['unet.encoders.1.0.conv_merged.weight'] = old['model.diffusion_model.input_blocks.1.0.out_layers.3.weight']
new['diffusion']['unet.encoders.1.0.conv_merged.bias'] = old['model.diffusion_model.input_blocks.1.0.out_layers.3.bias']
new['diffusion']['unet.encoders.1.1.groupnorm.weight'] = old['model.diffusion_model.input_blocks.1.1.norm.weight']
new['diffusion']['unet.encoders.1.1.groupnorm.bias'] = old['model.diffusion_model.input_blocks.1.1.norm.bias']
new['diffusion']['unet.encoders.1.1.conv_input.weight'] = old['model.diffusion_model.input_blocks.1.1.proj_in.weight']
new['diffusion']['unet.encoders.1.1.conv_input.bias'] = old['model.diffusion_model.input_blocks.1.1.proj_in.bias']
new['diffusion']['unet.encoders.1.1.attention_1.out_proj.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.encoders.1.1.attention_1.out_proj.bias'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.encoders.1.1.linear_geglu_1.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.encoders.1.1.linear_geglu_1.bias'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.encoders.1.1.linear_geglu_2.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.encoders.1.1.linear_geglu_2.bias'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.encoders.1.1.attention_2.q_proj.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.encoders.1.1.attention_2.k_proj.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.encoders.1.1.attention_2.v_proj.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.encoders.1.1.attention_2.out_proj.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.encoders.1.1.attention_2.out_proj.bias'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.encoders.1.1.layernorm_1.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.encoders.1.1.layernorm_1.bias'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.encoders.1.1.layernorm_2.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.encoders.1.1.layernorm_2.bias'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.encoders.1.1.layernorm_3.weight'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.encoders.1.1.layernorm_3.bias'] = old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.encoders.1.1.conv_output.weight'] = old['model.diffusion_model.input_blocks.1.1.proj_out.weight']
new['diffusion']['unet.encoders.1.1.conv_output.bias'] = old['model.diffusion_model.input_blocks.1.1.proj_out.bias']
new['diffusion']['unet.encoders.2.0.groupnorm_feature.weight'] = old['model.diffusion_model.input_blocks.2.0.in_layers.0.weight']
new['diffusion']['unet.encoders.2.0.groupnorm_feature.bias'] = old['model.diffusion_model.input_blocks.2.0.in_layers.0.bias']
new['diffusion']['unet.encoders.2.0.conv_feature.weight'] = old['model.diffusion_model.input_blocks.2.0.in_layers.2.weight']
new['diffusion']['unet.encoders.2.0.conv_feature.bias'] = old['model.diffusion_model.input_blocks.2.0.in_layers.2.bias']
new['diffusion']['unet.encoders.2.0.linear_time.weight'] = old['model.diffusion_model.input_blocks.2.0.emb_layers.1.weight']
new['diffusion']['unet.encoders.2.0.linear_time.bias'] = old['model.diffusion_model.input_blocks.2.0.emb_layers.1.bias']
new['diffusion']['unet.encoders.2.0.groupnorm_merged.weight'] = old['model.diffusion_model.input_blocks.2.0.out_layers.0.weight']
new['diffusion']['unet.encoders.2.0.groupnorm_merged.bias'] = old['model.diffusion_model.input_blocks.2.0.out_layers.0.bias']
new['diffusion']['unet.encoders.2.0.conv_merged.weight'] = old['model.diffusion_model.input_blocks.2.0.out_layers.3.weight']
new['diffusion']['unet.encoders.2.0.conv_merged.bias'] = old['model.diffusion_model.input_blocks.2.0.out_layers.3.bias']
new['diffusion']['unet.encoders.2.1.groupnorm.weight'] = old['model.diffusion_model.input_blocks.2.1.norm.weight']
new['diffusion']['unet.encoders.2.1.groupnorm.bias'] = old['model.diffusion_model.input_blocks.2.1.norm.bias']
new['diffusion']['unet.encoders.2.1.conv_input.weight'] = old['model.diffusion_model.input_blocks.2.1.proj_in.weight']
new['diffusion']['unet.encoders.2.1.conv_input.bias'] = old['model.diffusion_model.input_blocks.2.1.proj_in.bias']
new['diffusion']['unet.encoders.2.1.attention_1.out_proj.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.encoders.2.1.attention_1.out_proj.bias'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.encoders.2.1.linear_geglu_1.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.encoders.2.1.linear_geglu_1.bias'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.encoders.2.1.linear_geglu_2.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.encoders.2.1.linear_geglu_2.bias'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.encoders.2.1.attention_2.q_proj.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.encoders.2.1.attention_2.k_proj.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.encoders.2.1.attention_2.v_proj.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.encoders.2.1.attention_2.out_proj.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.encoders.2.1.attention_2.out_proj.bias'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.encoders.2.1.layernorm_1.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.encoders.2.1.layernorm_1.bias'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.encoders.2.1.layernorm_2.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.encoders.2.1.layernorm_2.bias'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.encoders.2.1.layernorm_3.weight'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.encoders.2.1.layernorm_3.bias'] = old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.encoders.2.1.conv_output.weight'] = old['model.diffusion_model.input_blocks.2.1.proj_out.weight']
new['diffusion']['unet.encoders.2.1.conv_output.bias'] = old['model.diffusion_model.input_blocks.2.1.proj_out.bias']
new['diffusion']['unet.encoders.3.0.weight'] = old['model.diffusion_model.input_blocks.3.0.op.weight']
new['diffusion']['unet.encoders.3.0.bias'] = old['model.diffusion_model.input_blocks.3.0.op.bias']
new['diffusion']['unet.encoders.4.0.groupnorm_feature.weight'] = old['model.diffusion_model.input_blocks.4.0.in_layers.0.weight']
new['diffusion']['unet.encoders.4.0.groupnorm_feature.bias'] = old['model.diffusion_model.input_blocks.4.0.in_layers.0.bias']
new['diffusion']['unet.encoders.4.0.conv_feature.weight'] = old['model.diffusion_model.input_blocks.4.0.in_layers.2.weight']
new['diffusion']['unet.encoders.4.0.conv_feature.bias'] = old['model.diffusion_model.input_blocks.4.0.in_layers.2.bias']
new['diffusion']['unet.encoders.4.0.linear_time.weight'] = old['model.diffusion_model.input_blocks.4.0.emb_layers.1.weight']
new['diffusion']['unet.encoders.4.0.linear_time.bias'] = old['model.diffusion_model.input_blocks.4.0.emb_layers.1.bias']
new['diffusion']['unet.encoders.4.0.groupnorm_merged.weight'] = old['model.diffusion_model.input_blocks.4.0.out_layers.0.weight']
new['diffusion']['unet.encoders.4.0.groupnorm_merged.bias'] = old['model.diffusion_model.input_blocks.4.0.out_layers.0.bias']
new['diffusion']['unet.encoders.4.0.conv_merged.weight'] = old['model.diffusion_model.input_blocks.4.0.out_layers.3.weight']
new['diffusion']['unet.encoders.4.0.conv_merged.bias'] = old['model.diffusion_model.input_blocks.4.0.out_layers.3.bias']
new['diffusion']['unet.encoders.4.0.residual_layer.weight'] = old['model.diffusion_model.input_blocks.4.0.skip_connection.weight']
new['diffusion']['unet.encoders.4.0.residual_layer.bias'] = old['model.diffusion_model.input_blocks.4.0.skip_connection.bias']
new['diffusion']['unet.encoders.4.1.groupnorm.weight'] = old['model.diffusion_model.input_blocks.4.1.norm.weight']
new['diffusion']['unet.encoders.4.1.groupnorm.bias'] = old['model.diffusion_model.input_blocks.4.1.norm.bias']
new['diffusion']['unet.encoders.4.1.conv_input.weight'] = old['model.diffusion_model.input_blocks.4.1.proj_in.weight']
new['diffusion']['unet.encoders.4.1.conv_input.bias'] = old['model.diffusion_model.input_blocks.4.1.proj_in.bias']
new['diffusion']['unet.encoders.4.1.attention_1.out_proj.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.encoders.4.1.attention_1.out_proj.bias'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.encoders.4.1.linear_geglu_1.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.encoders.4.1.linear_geglu_1.bias'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.encoders.4.1.linear_geglu_2.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.encoders.4.1.linear_geglu_2.bias'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.encoders.4.1.attention_2.q_proj.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.encoders.4.1.attention_2.k_proj.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.encoders.4.1.attention_2.v_proj.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.encoders.4.1.attention_2.out_proj.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.encoders.4.1.attention_2.out_proj.bias'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.encoders.4.1.layernorm_1.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.encoders.4.1.layernorm_1.bias'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.encoders.4.1.layernorm_2.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.encoders.4.1.layernorm_2.bias'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.encoders.4.1.layernorm_3.weight'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.encoders.4.1.layernorm_3.bias'] = old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.encoders.4.1.conv_output.weight'] = old['model.diffusion_model.input_blocks.4.1.proj_out.weight']
new['diffusion']['unet.encoders.4.1.conv_output.bias'] = old['model.diffusion_model.input_blocks.4.1.proj_out.bias']
new['diffusion']['unet.encoders.5.0.groupnorm_feature.weight'] = old['model.diffusion_model.input_blocks.5.0.in_layers.0.weight']
new['diffusion']['unet.encoders.5.0.groupnorm_feature.bias'] = old['model.diffusion_model.input_blocks.5.0.in_layers.0.bias']
new['diffusion']['unet.encoders.5.0.conv_feature.weight'] = old['model.diffusion_model.input_blocks.5.0.in_layers.2.weight']
new['diffusion']['unet.encoders.5.0.conv_feature.bias'] = old['model.diffusion_model.input_blocks.5.0.in_layers.2.bias']
new['diffusion']['unet.encoders.5.0.linear_time.weight'] = old['model.diffusion_model.input_blocks.5.0.emb_layers.1.weight']
new['diffusion']['unet.encoders.5.0.linear_time.bias'] = old['model.diffusion_model.input_blocks.5.0.emb_layers.1.bias']
new['diffusion']['unet.encoders.5.0.groupnorm_merged.weight'] = old['model.diffusion_model.input_blocks.5.0.out_layers.0.weight']
new['diffusion']['unet.encoders.5.0.groupnorm_merged.bias'] = old['model.diffusion_model.input_blocks.5.0.out_layers.0.bias']
new['diffusion']['unet.encoders.5.0.conv_merged.weight'] = old['model.diffusion_model.input_blocks.5.0.out_layers.3.weight']
new['diffusion']['unet.encoders.5.0.conv_merged.bias'] = old['model.diffusion_model.input_blocks.5.0.out_layers.3.bias']
new['diffusion']['unet.encoders.5.1.groupnorm.weight'] = old['model.diffusion_model.input_blocks.5.1.norm.weight']
new['diffusion']['unet.encoders.5.1.groupnorm.bias'] = old['model.diffusion_model.input_blocks.5.1.norm.bias']
new['diffusion']['unet.encoders.5.1.conv_input.weight'] = old['model.diffusion_model.input_blocks.5.1.proj_in.weight']
new['diffusion']['unet.encoders.5.1.conv_input.bias'] = old['model.diffusion_model.input_blocks.5.1.proj_in.bias']
new['diffusion']['unet.encoders.5.1.attention_1.out_proj.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.encoders.5.1.attention_1.out_proj.bias'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.encoders.5.1.linear_geglu_1.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.encoders.5.1.linear_geglu_1.bias'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.encoders.5.1.linear_geglu_2.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.encoders.5.1.linear_geglu_2.bias'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.encoders.5.1.attention_2.q_proj.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.encoders.5.1.attention_2.k_proj.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.encoders.5.1.attention_2.v_proj.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.encoders.5.1.attention_2.out_proj.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.encoders.5.1.attention_2.out_proj.bias'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.encoders.5.1.layernorm_1.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.encoders.5.1.layernorm_1.bias'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.encoders.5.1.layernorm_2.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.encoders.5.1.layernorm_2.bias'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.encoders.5.1.layernorm_3.weight'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.encoders.5.1.layernorm_3.bias'] = old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.encoders.5.1.conv_output.weight'] = old['model.diffusion_model.input_blocks.5.1.proj_out.weight']
new['diffusion']['unet.encoders.5.1.conv_output.bias'] = old['model.diffusion_model.input_blocks.5.1.proj_out.bias']
new['diffusion']['unet.encoders.6.0.weight'] = old['model.diffusion_model.input_blocks.6.0.op.weight']
new['diffusion']['unet.encoders.6.0.bias'] = old['model.diffusion_model.input_blocks.6.0.op.bias']
new['diffusion']['unet.encoders.7.0.groupnorm_feature.weight'] = old['model.diffusion_model.input_blocks.7.0.in_layers.0.weight']
new['diffusion']['unet.encoders.7.0.groupnorm_feature.bias'] = old['model.diffusion_model.input_blocks.7.0.in_layers.0.bias']
new['diffusion']['unet.encoders.7.0.conv_feature.weight'] = old['model.diffusion_model.input_blocks.7.0.in_layers.2.weight']
new['diffusion']['unet.encoders.7.0.conv_feature.bias'] = old['model.diffusion_model.input_blocks.7.0.in_layers.2.bias']
new['diffusion']['unet.encoders.7.0.linear_time.weight'] = old['model.diffusion_model.input_blocks.7.0.emb_layers.1.weight']
new['diffusion']['unet.encoders.7.0.linear_time.bias'] = old['model.diffusion_model.input_blocks.7.0.emb_layers.1.bias']
new['diffusion']['unet.encoders.7.0.groupnorm_merged.weight'] = old['model.diffusion_model.input_blocks.7.0.out_layers.0.weight']
new['diffusion']['unet.encoders.7.0.groupnorm_merged.bias'] = old['model.diffusion_model.input_blocks.7.0.out_layers.0.bias']
new['diffusion']['unet.encoders.7.0.conv_merged.weight'] = old['model.diffusion_model.input_blocks.7.0.out_layers.3.weight']
new['diffusion']['unet.encoders.7.0.conv_merged.bias'] = old['model.diffusion_model.input_blocks.7.0.out_layers.3.bias']
new['diffusion']['unet.encoders.7.0.residual_layer.weight'] = old['model.diffusion_model.input_blocks.7.0.skip_connection.weight']
new['diffusion']['unet.encoders.7.0.residual_layer.bias'] = old['model.diffusion_model.input_blocks.7.0.skip_connection.bias']
new['diffusion']['unet.encoders.7.1.groupnorm.weight'] = old['model.diffusion_model.input_blocks.7.1.norm.weight']
new['diffusion']['unet.encoders.7.1.groupnorm.bias'] = old['model.diffusion_model.input_blocks.7.1.norm.bias']
new['diffusion']['unet.encoders.7.1.conv_input.weight'] = old['model.diffusion_model.input_blocks.7.1.proj_in.weight']
new['diffusion']['unet.encoders.7.1.conv_input.bias'] = old['model.diffusion_model.input_blocks.7.1.proj_in.bias']
new['diffusion']['unet.encoders.7.1.attention_1.out_proj.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.encoders.7.1.attention_1.out_proj.bias'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.encoders.7.1.linear_geglu_1.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.encoders.7.1.linear_geglu_1.bias'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.encoders.7.1.linear_geglu_2.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.encoders.7.1.linear_geglu_2.bias'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.encoders.7.1.attention_2.q_proj.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.encoders.7.1.attention_2.k_proj.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.encoders.7.1.attention_2.v_proj.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.encoders.7.1.attention_2.out_proj.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.encoders.7.1.attention_2.out_proj.bias'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.encoders.7.1.layernorm_1.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.encoders.7.1.layernorm_1.bias'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.encoders.7.1.layernorm_2.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.encoders.7.1.layernorm_2.bias'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.encoders.7.1.layernorm_3.weight'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.encoders.7.1.layernorm_3.bias'] = old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.encoders.7.1.conv_output.weight'] = old['model.diffusion_model.input_blocks.7.1.proj_out.weight']
new['diffusion']['unet.encoders.7.1.conv_output.bias'] = old['model.diffusion_model.input_blocks.7.1.proj_out.bias']
new['diffusion']['unet.encoders.8.0.groupnorm_feature.weight'] = old['model.diffusion_model.input_blocks.8.0.in_layers.0.weight']
new['diffusion']['unet.encoders.8.0.groupnorm_feature.bias'] = old['model.diffusion_model.input_blocks.8.0.in_layers.0.bias']
new['diffusion']['unet.encoders.8.0.conv_feature.weight'] = old['model.diffusion_model.input_blocks.8.0.in_layers.2.weight']
new['diffusion']['unet.encoders.8.0.conv_feature.bias'] = old['model.diffusion_model.input_blocks.8.0.in_layers.2.bias']
new['diffusion']['unet.encoders.8.0.linear_time.weight'] = old['model.diffusion_model.input_blocks.8.0.emb_layers.1.weight']
new['diffusion']['unet.encoders.8.0.linear_time.bias'] = old['model.diffusion_model.input_blocks.8.0.emb_layers.1.bias']
new['diffusion']['unet.encoders.8.0.groupnorm_merged.weight'] = old['model.diffusion_model.input_blocks.8.0.out_layers.0.weight']
new['diffusion']['unet.encoders.8.0.groupnorm_merged.bias'] = old['model.diffusion_model.input_blocks.8.0.out_layers.0.bias']
new['diffusion']['unet.encoders.8.0.conv_merged.weight'] = old['model.diffusion_model.input_blocks.8.0.out_layers.3.weight']
new['diffusion']['unet.encoders.8.0.conv_merged.bias'] = old['model.diffusion_model.input_blocks.8.0.out_layers.3.bias']
new['diffusion']['unet.encoders.8.1.groupnorm.weight'] = old['model.diffusion_model.input_blocks.8.1.norm.weight']
new['diffusion']['unet.encoders.8.1.groupnorm.bias'] = old['model.diffusion_model.input_blocks.8.1.norm.bias']
new['diffusion']['unet.encoders.8.1.conv_input.weight'] = old['model.diffusion_model.input_blocks.8.1.proj_in.weight']
new['diffusion']['unet.encoders.8.1.conv_input.bias'] = old['model.diffusion_model.input_blocks.8.1.proj_in.bias']
new['diffusion']['unet.encoders.8.1.attention_1.out_proj.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.encoders.8.1.attention_1.out_proj.bias'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.encoders.8.1.linear_geglu_1.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.encoders.8.1.linear_geglu_1.bias'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.encoders.8.1.linear_geglu_2.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.encoders.8.1.linear_geglu_2.bias'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.encoders.8.1.attention_2.q_proj.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.encoders.8.1.attention_2.k_proj.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.encoders.8.1.attention_2.v_proj.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.encoders.8.1.attention_2.out_proj.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.encoders.8.1.attention_2.out_proj.bias'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.encoders.8.1.layernorm_1.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.encoders.8.1.layernorm_1.bias'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.encoders.8.1.layernorm_2.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.encoders.8.1.layernorm_2.bias'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.encoders.8.1.layernorm_3.weight'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.encoders.8.1.layernorm_3.bias'] = old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.encoders.8.1.conv_output.weight'] = old['model.diffusion_model.input_blocks.8.1.proj_out.weight']
new['diffusion']['unet.encoders.8.1.conv_output.bias'] = old['model.diffusion_model.input_blocks.8.1.proj_out.bias']
new['diffusion']['unet.encoders.9.0.weight'] = old['model.diffusion_model.input_blocks.9.0.op.weight']
new['diffusion']['unet.encoders.9.0.bias'] = old['model.diffusion_model.input_blocks.9.0.op.bias']
new['diffusion']['unet.encoders.10.0.groupnorm_feature.weight'] = old['model.diffusion_model.input_blocks.10.0.in_layers.0.weight']
new['diffusion']['unet.encoders.10.0.groupnorm_feature.bias'] = old['model.diffusion_model.input_blocks.10.0.in_layers.0.bias']
new['diffusion']['unet.encoders.10.0.conv_feature.weight'] = old['model.diffusion_model.input_blocks.10.0.in_layers.2.weight']
new['diffusion']['unet.encoders.10.0.conv_feature.bias'] = old['model.diffusion_model.input_blocks.10.0.in_layers.2.bias']
new['diffusion']['unet.encoders.10.0.linear_time.weight'] = old['model.diffusion_model.input_blocks.10.0.emb_layers.1.weight']
new['diffusion']['unet.encoders.10.0.linear_time.bias'] = old['model.diffusion_model.input_blocks.10.0.emb_layers.1.bias']
new['diffusion']['unet.encoders.10.0.groupnorm_merged.weight'] = old['model.diffusion_model.input_blocks.10.0.out_layers.0.weight']
new['diffusion']['unet.encoders.10.0.groupnorm_merged.bias'] = old['model.diffusion_model.input_blocks.10.0.out_layers.0.bias']
new['diffusion']['unet.encoders.10.0.conv_merged.weight'] = old['model.diffusion_model.input_blocks.10.0.out_layers.3.weight']
new['diffusion']['unet.encoders.10.0.conv_merged.bias'] = old['model.diffusion_model.input_blocks.10.0.out_layers.3.bias']
new['diffusion']['unet.encoders.11.0.groupnorm_feature.weight'] = old['model.diffusion_model.input_blocks.11.0.in_layers.0.weight']
new['diffusion']['unet.encoders.11.0.groupnorm_feature.bias'] = old['model.diffusion_model.input_blocks.11.0.in_layers.0.bias']
new['diffusion']['unet.encoders.11.0.conv_feature.weight'] = old['model.diffusion_model.input_blocks.11.0.in_layers.2.weight']
new['diffusion']['unet.encoders.11.0.conv_feature.bias'] = old['model.diffusion_model.input_blocks.11.0.in_layers.2.bias']
new['diffusion']['unet.encoders.11.0.linear_time.weight'] = old['model.diffusion_model.input_blocks.11.0.emb_layers.1.weight']
new['diffusion']['unet.encoders.11.0.linear_time.bias'] = old['model.diffusion_model.input_blocks.11.0.emb_layers.1.bias']
new['diffusion']['unet.encoders.11.0.groupnorm_merged.weight'] = old['model.diffusion_model.input_blocks.11.0.out_layers.0.weight']
new['diffusion']['unet.encoders.11.0.groupnorm_merged.bias'] = old['model.diffusion_model.input_blocks.11.0.out_layers.0.bias']
new['diffusion']['unet.encoders.11.0.conv_merged.weight'] = old['model.diffusion_model.input_blocks.11.0.out_layers.3.weight']
new['diffusion']['unet.encoders.11.0.conv_merged.bias'] = old['model.diffusion_model.input_blocks.11.0.out_layers.3.bias']
new['diffusion']['unet.bottleneck.0.groupnorm_feature.weight'] = old['model.diffusion_model.middle_block.0.in_layers.0.weight']
new['diffusion']['unet.bottleneck.0.groupnorm_feature.bias'] = old['model.diffusion_model.middle_block.0.in_layers.0.bias']
new['diffusion']['unet.bottleneck.0.conv_feature.weight'] = old['model.diffusion_model.middle_block.0.in_layers.2.weight']
new['diffusion']['unet.bottleneck.0.conv_feature.bias'] = old['model.diffusion_model.middle_block.0.in_layers.2.bias']
new['diffusion']['unet.bottleneck.0.linear_time.weight'] = old['model.diffusion_model.middle_block.0.emb_layers.1.weight']
new['diffusion']['unet.bottleneck.0.linear_time.bias'] = old['model.diffusion_model.middle_block.0.emb_layers.1.bias']
new['diffusion']['unet.bottleneck.0.groupnorm_merged.weight'] = old['model.diffusion_model.middle_block.0.out_layers.0.weight']
new['diffusion']['unet.bottleneck.0.groupnorm_merged.bias'] = old['model.diffusion_model.middle_block.0.out_layers.0.bias']
new['diffusion']['unet.bottleneck.0.conv_merged.weight'] = old['model.diffusion_model.middle_block.0.out_layers.3.weight']
new['diffusion']['unet.bottleneck.0.conv_merged.bias'] = old['model.diffusion_model.middle_block.0.out_layers.3.bias']
new['diffusion']['unet.bottleneck.1.groupnorm.weight'] = old['model.diffusion_model.middle_block.1.norm.weight']
new['diffusion']['unet.bottleneck.1.groupnorm.bias'] = old['model.diffusion_model.middle_block.1.norm.bias']
new['diffusion']['unet.bottleneck.1.conv_input.weight'] = old['model.diffusion_model.middle_block.1.proj_in.weight']
new['diffusion']['unet.bottleneck.1.conv_input.bias'] = old['model.diffusion_model.middle_block.1.proj_in.bias']
new['diffusion']['unet.bottleneck.1.attention_1.out_proj.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.bottleneck.1.attention_1.out_proj.bias'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.bottleneck.1.linear_geglu_1.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.bottleneck.1.linear_geglu_1.bias'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.bottleneck.1.linear_geglu_2.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.bottleneck.1.linear_geglu_2.bias'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.bottleneck.1.attention_2.q_proj.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.bottleneck.1.attention_2.k_proj.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.bottleneck.1.attention_2.v_proj.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.bottleneck.1.attention_2.out_proj.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.bottleneck.1.attention_2.out_proj.bias'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.bottleneck.1.layernorm_1.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.bottleneck.1.layernorm_1.bias'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.bottleneck.1.layernorm_2.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.bottleneck.1.layernorm_2.bias'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.bottleneck.1.layernorm_3.weight'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.bottleneck.1.layernorm_3.bias'] = old['model.diffusion_model.middle_block.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.bottleneck.1.conv_output.weight'] = old['model.diffusion_model.middle_block.1.proj_out.weight']
new['diffusion']['unet.bottleneck.1.conv_output.bias'] = old['model.diffusion_model.middle_block.1.proj_out.bias']
new['diffusion']['unet.bottleneck.2.groupnorm_feature.weight'] = old['model.diffusion_model.middle_block.2.in_layers.0.weight']
new['diffusion']['unet.bottleneck.2.groupnorm_feature.bias'] = old['model.diffusion_model.middle_block.2.in_layers.0.bias']
new['diffusion']['unet.bottleneck.2.conv_feature.weight'] = old['model.diffusion_model.middle_block.2.in_layers.2.weight']
new['diffusion']['unet.bottleneck.2.conv_feature.bias'] = old['model.diffusion_model.middle_block.2.in_layers.2.bias']
new['diffusion']['unet.bottleneck.2.linear_time.weight'] = old['model.diffusion_model.middle_block.2.emb_layers.1.weight']
new['diffusion']['unet.bottleneck.2.linear_time.bias'] = old['model.diffusion_model.middle_block.2.emb_layers.1.bias']
new['diffusion']['unet.bottleneck.2.groupnorm_merged.weight'] = old['model.diffusion_model.middle_block.2.out_layers.0.weight']
new['diffusion']['unet.bottleneck.2.groupnorm_merged.bias'] = old['model.diffusion_model.middle_block.2.out_layers.0.bias']
new['diffusion']['unet.bottleneck.2.conv_merged.weight'] = old['model.diffusion_model.middle_block.2.out_layers.3.weight']
new['diffusion']['unet.bottleneck.2.conv_merged.bias'] = old['model.diffusion_model.middle_block.2.out_layers.3.bias']
new['diffusion']['unet.decoders.0.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.0.0.in_layers.0.weight']
new['diffusion']['unet.decoders.0.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.0.0.in_layers.0.bias']
new['diffusion']['unet.decoders.0.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.0.0.in_layers.2.weight']
new['diffusion']['unet.decoders.0.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.0.0.in_layers.2.bias']
new['diffusion']['unet.decoders.0.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.0.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.0.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.0.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.0.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.0.0.out_layers.0.weight']
new['diffusion']['unet.decoders.0.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.0.0.out_layers.0.bias']
new['diffusion']['unet.decoders.0.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.0.0.out_layers.3.weight']
new['diffusion']['unet.decoders.0.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.0.0.out_layers.3.bias']
new['diffusion']['unet.decoders.0.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.0.0.skip_connection.weight']
new['diffusion']['unet.decoders.0.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.0.0.skip_connection.bias']
new['diffusion']['unet.decoders.1.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.1.0.in_layers.0.weight']
new['diffusion']['unet.decoders.1.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.1.0.in_layers.0.bias']
new['diffusion']['unet.decoders.1.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.1.0.in_layers.2.weight']
new['diffusion']['unet.decoders.1.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.1.0.in_layers.2.bias']
new['diffusion']['unet.decoders.1.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.1.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.1.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.1.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.1.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.1.0.out_layers.0.weight']
new['diffusion']['unet.decoders.1.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.1.0.out_layers.0.bias']
new['diffusion']['unet.decoders.1.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.1.0.out_layers.3.weight']
new['diffusion']['unet.decoders.1.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.1.0.out_layers.3.bias']
new['diffusion']['unet.decoders.1.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.1.0.skip_connection.weight']
new['diffusion']['unet.decoders.1.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.1.0.skip_connection.bias']
new['diffusion']['unet.decoders.2.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.2.0.in_layers.0.weight']
new['diffusion']['unet.decoders.2.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.2.0.in_layers.0.bias']
new['diffusion']['unet.decoders.2.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.2.0.in_layers.2.weight']
new['diffusion']['unet.decoders.2.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.2.0.in_layers.2.bias']
new['diffusion']['unet.decoders.2.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.2.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.2.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.2.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.2.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.2.0.out_layers.0.weight']
new['diffusion']['unet.decoders.2.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.2.0.out_layers.0.bias']
new['diffusion']['unet.decoders.2.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.2.0.out_layers.3.weight']
new['diffusion']['unet.decoders.2.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.2.0.out_layers.3.bias']
new['diffusion']['unet.decoders.2.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.2.0.skip_connection.weight']
new['diffusion']['unet.decoders.2.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.2.0.skip_connection.bias']
new['diffusion']['unet.decoders.2.1.conv.weight'] = old['model.diffusion_model.output_blocks.2.1.conv.weight']
new['diffusion']['unet.decoders.2.1.conv.bias'] = old['model.diffusion_model.output_blocks.2.1.conv.bias']
new['diffusion']['unet.decoders.3.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.3.0.in_layers.0.weight']
new['diffusion']['unet.decoders.3.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.3.0.in_layers.0.bias']
new['diffusion']['unet.decoders.3.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.3.0.in_layers.2.weight']
new['diffusion']['unet.decoders.3.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.3.0.in_layers.2.bias']
new['diffusion']['unet.decoders.3.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.3.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.3.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.3.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.3.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.3.0.out_layers.0.weight']
new['diffusion']['unet.decoders.3.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.3.0.out_layers.0.bias']
new['diffusion']['unet.decoders.3.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.3.0.out_layers.3.weight']
new['diffusion']['unet.decoders.3.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.3.0.out_layers.3.bias']
new['diffusion']['unet.decoders.3.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.3.0.skip_connection.weight']
new['diffusion']['unet.decoders.3.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.3.0.skip_connection.bias']
new['diffusion']['unet.decoders.3.1.groupnorm.weight'] = old['model.diffusion_model.output_blocks.3.1.norm.weight']
new['diffusion']['unet.decoders.3.1.groupnorm.bias'] = old['model.diffusion_model.output_blocks.3.1.norm.bias']
new['diffusion']['unet.decoders.3.1.conv_input.weight'] = old['model.diffusion_model.output_blocks.3.1.proj_in.weight']
new['diffusion']['unet.decoders.3.1.conv_input.bias'] = old['model.diffusion_model.output_blocks.3.1.proj_in.bias']
new['diffusion']['unet.decoders.3.1.attention_1.out_proj.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.decoders.3.1.attention_1.out_proj.bias'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.decoders.3.1.linear_geglu_1.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.decoders.3.1.linear_geglu_1.bias'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.decoders.3.1.linear_geglu_2.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.decoders.3.1.linear_geglu_2.bias'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.decoders.3.1.attention_2.q_proj.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.decoders.3.1.attention_2.k_proj.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.decoders.3.1.attention_2.v_proj.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.decoders.3.1.attention_2.out_proj.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.decoders.3.1.attention_2.out_proj.bias'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.decoders.3.1.layernorm_1.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.decoders.3.1.layernorm_1.bias'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.decoders.3.1.layernorm_2.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.decoders.3.1.layernorm_2.bias'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.decoders.3.1.layernorm_3.weight'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.decoders.3.1.layernorm_3.bias'] = old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.decoders.3.1.conv_output.weight'] = old['model.diffusion_model.output_blocks.3.1.proj_out.weight']
new['diffusion']['unet.decoders.3.1.conv_output.bias'] = old['model.diffusion_model.output_blocks.3.1.proj_out.bias']
new['diffusion']['unet.decoders.4.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.4.0.in_layers.0.weight']
new['diffusion']['unet.decoders.4.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.4.0.in_layers.0.bias']
new['diffusion']['unet.decoders.4.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.4.0.in_layers.2.weight']
new['diffusion']['unet.decoders.4.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.4.0.in_layers.2.bias']
new['diffusion']['unet.decoders.4.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.4.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.4.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.4.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.4.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.4.0.out_layers.0.weight']
new['diffusion']['unet.decoders.4.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.4.0.out_layers.0.bias']
new['diffusion']['unet.decoders.4.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.4.0.out_layers.3.weight']
new['diffusion']['unet.decoders.4.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.4.0.out_layers.3.bias']
new['diffusion']['unet.decoders.4.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.4.0.skip_connection.weight']
new['diffusion']['unet.decoders.4.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.4.0.skip_connection.bias']
new['diffusion']['unet.decoders.4.1.groupnorm.weight'] = old['model.diffusion_model.output_blocks.4.1.norm.weight']
new['diffusion']['unet.decoders.4.1.groupnorm.bias'] = old['model.diffusion_model.output_blocks.4.1.norm.bias']
new['diffusion']['unet.decoders.4.1.conv_input.weight'] = old['model.diffusion_model.output_blocks.4.1.proj_in.weight']
new['diffusion']['unet.decoders.4.1.conv_input.bias'] = old['model.diffusion_model.output_blocks.4.1.proj_in.bias']
new['diffusion']['unet.decoders.4.1.attention_1.out_proj.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.decoders.4.1.attention_1.out_proj.bias'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.decoders.4.1.linear_geglu_1.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.decoders.4.1.linear_geglu_1.bias'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.decoders.4.1.linear_geglu_2.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.decoders.4.1.linear_geglu_2.bias'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.decoders.4.1.attention_2.q_proj.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.decoders.4.1.attention_2.k_proj.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.decoders.4.1.attention_2.v_proj.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.decoders.4.1.attention_2.out_proj.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.decoders.4.1.attention_2.out_proj.bias'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.decoders.4.1.layernorm_1.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.decoders.4.1.layernorm_1.bias'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.decoders.4.1.layernorm_2.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.decoders.4.1.layernorm_2.bias'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.decoders.4.1.layernorm_3.weight'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.decoders.4.1.layernorm_3.bias'] = old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.decoders.4.1.conv_output.weight'] = old['model.diffusion_model.output_blocks.4.1.proj_out.weight']
new['diffusion']['unet.decoders.4.1.conv_output.bias'] = old['model.diffusion_model.output_blocks.4.1.proj_out.bias']
new['diffusion']['unet.decoders.5.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.5.0.in_layers.0.weight']
new['diffusion']['unet.decoders.5.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.5.0.in_layers.0.bias']
new['diffusion']['unet.decoders.5.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.5.0.in_layers.2.weight']
new['diffusion']['unet.decoders.5.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.5.0.in_layers.2.bias']
new['diffusion']['unet.decoders.5.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.5.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.5.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.5.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.5.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.5.0.out_layers.0.weight']
new['diffusion']['unet.decoders.5.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.5.0.out_layers.0.bias']
new['diffusion']['unet.decoders.5.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.5.0.out_layers.3.weight']
new['diffusion']['unet.decoders.5.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.5.0.out_layers.3.bias']
new['diffusion']['unet.decoders.5.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.5.0.skip_connection.weight']
new['diffusion']['unet.decoders.5.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.5.0.skip_connection.bias']
new['diffusion']['unet.decoders.5.1.groupnorm.weight'] = old['model.diffusion_model.output_blocks.5.1.norm.weight']
new['diffusion']['unet.decoders.5.1.groupnorm.bias'] = old['model.diffusion_model.output_blocks.5.1.norm.bias']
new['diffusion']['unet.decoders.5.1.conv_input.weight'] = old['model.diffusion_model.output_blocks.5.1.proj_in.weight']
new['diffusion']['unet.decoders.5.1.conv_input.bias'] = old['model.diffusion_model.output_blocks.5.1.proj_in.bias']
new['diffusion']['unet.decoders.5.1.attention_1.out_proj.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.decoders.5.1.attention_1.out_proj.bias'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.decoders.5.1.linear_geglu_1.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.decoders.5.1.linear_geglu_1.bias'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.decoders.5.1.linear_geglu_2.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.decoders.5.1.linear_geglu_2.bias'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.decoders.5.1.attention_2.q_proj.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.decoders.5.1.attention_2.k_proj.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.decoders.5.1.attention_2.v_proj.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.decoders.5.1.attention_2.out_proj.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.decoders.5.1.attention_2.out_proj.bias'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.decoders.5.1.layernorm_1.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.decoders.5.1.layernorm_1.bias'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.decoders.5.1.layernorm_2.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.decoders.5.1.layernorm_2.bias'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.decoders.5.1.layernorm_3.weight'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.decoders.5.1.layernorm_3.bias'] = old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.decoders.5.1.conv_output.weight'] = old['model.diffusion_model.output_blocks.5.1.proj_out.weight']
new['diffusion']['unet.decoders.5.1.conv_output.bias'] = old['model.diffusion_model.output_blocks.5.1.proj_out.bias']
new['diffusion']['unet.decoders.5.2.conv.weight'] = old['model.diffusion_model.output_blocks.5.2.conv.weight']
new['diffusion']['unet.decoders.5.2.conv.bias'] = old['model.diffusion_model.output_blocks.5.2.conv.bias']
new['diffusion']['unet.decoders.6.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.6.0.in_layers.0.weight']
new['diffusion']['unet.decoders.6.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.6.0.in_layers.0.bias']
new['diffusion']['unet.decoders.6.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.6.0.in_layers.2.weight']
new['diffusion']['unet.decoders.6.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.6.0.in_layers.2.bias']
new['diffusion']['unet.decoders.6.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.6.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.6.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.6.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.6.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.6.0.out_layers.0.weight']
new['diffusion']['unet.decoders.6.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.6.0.out_layers.0.bias']
new['diffusion']['unet.decoders.6.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.6.0.out_layers.3.weight']
new['diffusion']['unet.decoders.6.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.6.0.out_layers.3.bias']
new['diffusion']['unet.decoders.6.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.6.0.skip_connection.weight']
new['diffusion']['unet.decoders.6.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.6.0.skip_connection.bias']
new['diffusion']['unet.decoders.6.1.groupnorm.weight'] = old['model.diffusion_model.output_blocks.6.1.norm.weight']
new['diffusion']['unet.decoders.6.1.groupnorm.bias'] = old['model.diffusion_model.output_blocks.6.1.norm.bias']
new['diffusion']['unet.decoders.6.1.conv_input.weight'] = old['model.diffusion_model.output_blocks.6.1.proj_in.weight']
new['diffusion']['unet.decoders.6.1.conv_input.bias'] = old['model.diffusion_model.output_blocks.6.1.proj_in.bias']
new['diffusion']['unet.decoders.6.1.attention_1.out_proj.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.decoders.6.1.attention_1.out_proj.bias'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.decoders.6.1.linear_geglu_1.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.decoders.6.1.linear_geglu_1.bias'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.decoders.6.1.linear_geglu_2.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.decoders.6.1.linear_geglu_2.bias'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.decoders.6.1.attention_2.q_proj.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.decoders.6.1.attention_2.k_proj.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.decoders.6.1.attention_2.v_proj.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.decoders.6.1.attention_2.out_proj.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.decoders.6.1.attention_2.out_proj.bias'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.decoders.6.1.layernorm_1.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.decoders.6.1.layernorm_1.bias'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.decoders.6.1.layernorm_2.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.decoders.6.1.layernorm_2.bias'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.decoders.6.1.layernorm_3.weight'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.decoders.6.1.layernorm_3.bias'] = old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.decoders.6.1.conv_output.weight'] = old['model.diffusion_model.output_blocks.6.1.proj_out.weight']
new['diffusion']['unet.decoders.6.1.conv_output.bias'] = old['model.diffusion_model.output_blocks.6.1.proj_out.bias']
new['diffusion']['unet.decoders.7.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.7.0.in_layers.0.weight']
new['diffusion']['unet.decoders.7.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.7.0.in_layers.0.bias']
new['diffusion']['unet.decoders.7.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.7.0.in_layers.2.weight']
new['diffusion']['unet.decoders.7.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.7.0.in_layers.2.bias']
new['diffusion']['unet.decoders.7.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.7.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.7.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.7.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.7.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.7.0.out_layers.0.weight']
new['diffusion']['unet.decoders.7.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.7.0.out_layers.0.bias']
new['diffusion']['unet.decoders.7.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.7.0.out_layers.3.weight']
new['diffusion']['unet.decoders.7.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.7.0.out_layers.3.bias']
new['diffusion']['unet.decoders.7.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.7.0.skip_connection.weight']
new['diffusion']['unet.decoders.7.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.7.0.skip_connection.bias']
new['diffusion']['unet.decoders.7.1.groupnorm.weight'] = old['model.diffusion_model.output_blocks.7.1.norm.weight']
new['diffusion']['unet.decoders.7.1.groupnorm.bias'] = old['model.diffusion_model.output_blocks.7.1.norm.bias']
new['diffusion']['unet.decoders.7.1.conv_input.weight'] = old['model.diffusion_model.output_blocks.7.1.proj_in.weight']
new['diffusion']['unet.decoders.7.1.conv_input.bias'] = old['model.diffusion_model.output_blocks.7.1.proj_in.bias']
new['diffusion']['unet.decoders.7.1.attention_1.out_proj.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.decoders.7.1.attention_1.out_proj.bias'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.decoders.7.1.linear_geglu_1.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.decoders.7.1.linear_geglu_1.bias'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.decoders.7.1.linear_geglu_2.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.decoders.7.1.linear_geglu_2.bias'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.decoders.7.1.attention_2.q_proj.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.decoders.7.1.attention_2.k_proj.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.decoders.7.1.attention_2.v_proj.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.decoders.7.1.attention_2.out_proj.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.decoders.7.1.attention_2.out_proj.bias'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.decoders.7.1.layernorm_1.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.decoders.7.1.layernorm_1.bias'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.decoders.7.1.layernorm_2.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.decoders.7.1.layernorm_2.bias'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.decoders.7.1.layernorm_3.weight'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.decoders.7.1.layernorm_3.bias'] = old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.decoders.7.1.conv_output.weight'] = old['model.diffusion_model.output_blocks.7.1.proj_out.weight']
new['diffusion']['unet.decoders.7.1.conv_output.bias'] = old['model.diffusion_model.output_blocks.7.1.proj_out.bias']
new['diffusion']['unet.decoders.8.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.8.0.in_layers.0.weight']
new['diffusion']['unet.decoders.8.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.8.0.in_layers.0.bias']
new['diffusion']['unet.decoders.8.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.8.0.in_layers.2.weight']
new['diffusion']['unet.decoders.8.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.8.0.in_layers.2.bias']
new['diffusion']['unet.decoders.8.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.8.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.8.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.8.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.8.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.8.0.out_layers.0.weight']
new['diffusion']['unet.decoders.8.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.8.0.out_layers.0.bias']
new['diffusion']['unet.decoders.8.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.8.0.out_layers.3.weight']
new['diffusion']['unet.decoders.8.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.8.0.out_layers.3.bias']
new['diffusion']['unet.decoders.8.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.8.0.skip_connection.weight']
new['diffusion']['unet.decoders.8.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.8.0.skip_connection.bias']
new['diffusion']['unet.decoders.8.1.groupnorm.weight'] = old['model.diffusion_model.output_blocks.8.1.norm.weight']
new['diffusion']['unet.decoders.8.1.groupnorm.bias'] = old['model.diffusion_model.output_blocks.8.1.norm.bias']
new['diffusion']['unet.decoders.8.1.conv_input.weight'] = old['model.diffusion_model.output_blocks.8.1.proj_in.weight']
new['diffusion']['unet.decoders.8.1.conv_input.bias'] = old['model.diffusion_model.output_blocks.8.1.proj_in.bias']
new['diffusion']['unet.decoders.8.1.attention_1.out_proj.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.decoders.8.1.attention_1.out_proj.bias'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.decoders.8.1.linear_geglu_1.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.decoders.8.1.linear_geglu_1.bias'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.decoders.8.1.linear_geglu_2.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.decoders.8.1.linear_geglu_2.bias'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.decoders.8.1.attention_2.q_proj.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.decoders.8.1.attention_2.k_proj.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.decoders.8.1.attention_2.v_proj.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.decoders.8.1.attention_2.out_proj.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.decoders.8.1.attention_2.out_proj.bias'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.decoders.8.1.layernorm_1.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.decoders.8.1.layernorm_1.bias'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.decoders.8.1.layernorm_2.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.decoders.8.1.layernorm_2.bias'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.decoders.8.1.layernorm_3.weight'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.decoders.8.1.layernorm_3.bias'] = old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.decoders.8.1.conv_output.weight'] = old['model.diffusion_model.output_blocks.8.1.proj_out.weight']
new['diffusion']['unet.decoders.8.1.conv_output.bias'] = old['model.diffusion_model.output_blocks.8.1.proj_out.bias']
new['diffusion']['unet.decoders.8.2.conv.weight'] = old['model.diffusion_model.output_blocks.8.2.conv.weight']
new['diffusion']['unet.decoders.8.2.conv.bias'] = old['model.diffusion_model.output_blocks.8.2.conv.bias']
new['diffusion']['unet.decoders.9.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.9.0.in_layers.0.weight']
new['diffusion']['unet.decoders.9.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.9.0.in_layers.0.bias']
new['diffusion']['unet.decoders.9.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.9.0.in_layers.2.weight']
new['diffusion']['unet.decoders.9.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.9.0.in_layers.2.bias']
new['diffusion']['unet.decoders.9.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.9.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.9.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.9.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.9.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.9.0.out_layers.0.weight']
new['diffusion']['unet.decoders.9.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.9.0.out_layers.0.bias']
new['diffusion']['unet.decoders.9.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.9.0.out_layers.3.weight']
new['diffusion']['unet.decoders.9.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.9.0.out_layers.3.bias']
new['diffusion']['unet.decoders.9.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.9.0.skip_connection.weight']
new['diffusion']['unet.decoders.9.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.9.0.skip_connection.bias']
new['diffusion']['unet.decoders.9.1.groupnorm.weight'] = old['model.diffusion_model.output_blocks.9.1.norm.weight']
new['diffusion']['unet.decoders.9.1.groupnorm.bias'] = old['model.diffusion_model.output_blocks.9.1.norm.bias']
new['diffusion']['unet.decoders.9.1.conv_input.weight'] = old['model.diffusion_model.output_blocks.9.1.proj_in.weight']
new['diffusion']['unet.decoders.9.1.conv_input.bias'] = old['model.diffusion_model.output_blocks.9.1.proj_in.bias']
new['diffusion']['unet.decoders.9.1.attention_1.out_proj.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.decoders.9.1.attention_1.out_proj.bias'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.decoders.9.1.linear_geglu_1.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.decoders.9.1.linear_geglu_1.bias'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.decoders.9.1.linear_geglu_2.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.decoders.9.1.linear_geglu_2.bias'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.decoders.9.1.attention_2.q_proj.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.decoders.9.1.attention_2.k_proj.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.decoders.9.1.attention_2.v_proj.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.decoders.9.1.attention_2.out_proj.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.decoders.9.1.attention_2.out_proj.bias'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.decoders.9.1.layernorm_1.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.decoders.9.1.layernorm_1.bias'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.decoders.9.1.layernorm_2.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.decoders.9.1.layernorm_2.bias'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.decoders.9.1.layernorm_3.weight'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.decoders.9.1.layernorm_3.bias'] = old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.decoders.9.1.conv_output.weight'] = old['model.diffusion_model.output_blocks.9.1.proj_out.weight']
new['diffusion']['unet.decoders.9.1.conv_output.bias'] = old['model.diffusion_model.output_blocks.9.1.proj_out.bias']
new['diffusion']['unet.decoders.10.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.10.0.in_layers.0.weight']
new['diffusion']['unet.decoders.10.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.10.0.in_layers.0.bias']
new['diffusion']['unet.decoders.10.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.10.0.in_layers.2.weight']
new['diffusion']['unet.decoders.10.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.10.0.in_layers.2.bias']
new['diffusion']['unet.decoders.10.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.10.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.10.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.10.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.10.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.10.0.out_layers.0.weight']
new['diffusion']['unet.decoders.10.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.10.0.out_layers.0.bias']
new['diffusion']['unet.decoders.10.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.10.0.out_layers.3.weight']
new['diffusion']['unet.decoders.10.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.10.0.out_layers.3.bias']
new['diffusion']['unet.decoders.10.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.10.0.skip_connection.weight']
new['diffusion']['unet.decoders.10.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.10.0.skip_connection.bias']
new['diffusion']['unet.decoders.10.1.groupnorm.weight'] = old['model.diffusion_model.output_blocks.10.1.norm.weight']
new['diffusion']['unet.decoders.10.1.groupnorm.bias'] = old['model.diffusion_model.output_blocks.10.1.norm.bias']
new['diffusion']['unet.decoders.10.1.conv_input.weight'] = old['model.diffusion_model.output_blocks.10.1.proj_in.weight']
new['diffusion']['unet.decoders.10.1.conv_input.bias'] = old['model.diffusion_model.output_blocks.10.1.proj_in.bias']
new['diffusion']['unet.decoders.10.1.attention_1.out_proj.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.decoders.10.1.attention_1.out_proj.bias'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.decoders.10.1.linear_geglu_1.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.decoders.10.1.linear_geglu_1.bias'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.decoders.10.1.linear_geglu_2.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.decoders.10.1.linear_geglu_2.bias'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.decoders.10.1.attention_2.q_proj.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.decoders.10.1.attention_2.k_proj.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.decoders.10.1.attention_2.v_proj.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.decoders.10.1.attention_2.out_proj.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.decoders.10.1.attention_2.out_proj.bias'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.decoders.10.1.layernorm_1.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.decoders.10.1.layernorm_1.bias'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.decoders.10.1.layernorm_2.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.decoders.10.1.layernorm_2.bias'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.decoders.10.1.layernorm_3.weight'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.decoders.10.1.layernorm_3.bias'] = old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.decoders.10.1.conv_output.weight'] = old['model.diffusion_model.output_blocks.10.1.proj_out.weight']
new['diffusion']['unet.decoders.10.1.conv_output.bias'] = old['model.diffusion_model.output_blocks.10.1.proj_out.bias']
new['diffusion']['unet.decoders.11.0.groupnorm_feature.weight'] = old['model.diffusion_model.output_blocks.11.0.in_layers.0.weight']
new['diffusion']['unet.decoders.11.0.groupnorm_feature.bias'] = old['model.diffusion_model.output_blocks.11.0.in_layers.0.bias']
new['diffusion']['unet.decoders.11.0.conv_feature.weight'] = old['model.diffusion_model.output_blocks.11.0.in_layers.2.weight']
new['diffusion']['unet.decoders.11.0.conv_feature.bias'] = old['model.diffusion_model.output_blocks.11.0.in_layers.2.bias']
new['diffusion']['unet.decoders.11.0.linear_time.weight'] = old['model.diffusion_model.output_blocks.11.0.emb_layers.1.weight']
new['diffusion']['unet.decoders.11.0.linear_time.bias'] = old['model.diffusion_model.output_blocks.11.0.emb_layers.1.bias']
new['diffusion']['unet.decoders.11.0.groupnorm_merged.weight'] = old['model.diffusion_model.output_blocks.11.0.out_layers.0.weight']
new['diffusion']['unet.decoders.11.0.groupnorm_merged.bias'] = old['model.diffusion_model.output_blocks.11.0.out_layers.0.bias']
new['diffusion']['unet.decoders.11.0.conv_merged.weight'] = old['model.diffusion_model.output_blocks.11.0.out_layers.3.weight']
new['diffusion']['unet.decoders.11.0.conv_merged.bias'] = old['model.diffusion_model.output_blocks.11.0.out_layers.3.bias']
new['diffusion']['unet.decoders.11.0.residual_layer.weight'] = old['model.diffusion_model.output_blocks.11.0.skip_connection.weight']
new['diffusion']['unet.decoders.11.0.residual_layer.bias'] = old['model.diffusion_model.output_blocks.11.0.skip_connection.bias']
new['diffusion']['unet.decoders.11.1.groupnorm.weight'] = old['model.diffusion_model.output_blocks.11.1.norm.weight']
new['diffusion']['unet.decoders.11.1.groupnorm.bias'] = old['model.diffusion_model.output_blocks.11.1.norm.bias']
new['diffusion']['unet.decoders.11.1.conv_input.weight'] = old['model.diffusion_model.output_blocks.11.1.proj_in.weight']
new['diffusion']['unet.decoders.11.1.conv_input.bias'] = old['model.diffusion_model.output_blocks.11.1.proj_in.bias']
new['diffusion']['unet.decoders.11.1.attention_1.out_proj.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn1.to_out.0.weight']
new['diffusion']['unet.decoders.11.1.attention_1.out_proj.bias'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn1.to_out.0.bias']
new['diffusion']['unet.decoders.11.1.linear_geglu_1.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.ff.net.0.proj.weight']
new['diffusion']['unet.decoders.11.1.linear_geglu_1.bias'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.ff.net.0.proj.bias']
new['diffusion']['unet.decoders.11.1.linear_geglu_2.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.ff.net.2.weight']
new['diffusion']['unet.decoders.11.1.linear_geglu_2.bias'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.ff.net.2.bias']
new['diffusion']['unet.decoders.11.1.attention_2.q_proj.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn2.to_q.weight']
new['diffusion']['unet.decoders.11.1.attention_2.k_proj.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn2.to_k.weight']
new['diffusion']['unet.decoders.11.1.attention_2.v_proj.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn2.to_v.weight']
new['diffusion']['unet.decoders.11.1.attention_2.out_proj.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn2.to_out.0.weight']
new['diffusion']['unet.decoders.11.1.attention_2.out_proj.bias'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn2.to_out.0.bias']
new['diffusion']['unet.decoders.11.1.layernorm_1.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.norm1.weight']
new['diffusion']['unet.decoders.11.1.layernorm_1.bias'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.norm1.bias']
new['diffusion']['unet.decoders.11.1.layernorm_2.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.norm2.weight']
new['diffusion']['unet.decoders.11.1.layernorm_2.bias'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.norm2.bias']
new['diffusion']['unet.decoders.11.1.layernorm_3.weight'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.norm3.weight']
new['diffusion']['unet.decoders.11.1.layernorm_3.bias'] = old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.norm3.bias']
new['diffusion']['unet.decoders.11.1.conv_output.weight'] = old['model.diffusion_model.output_blocks.11.1.proj_out.weight']
new['diffusion']['unet.decoders.11.1.conv_output.bias'] = old['model.diffusion_model.output_blocks.11.1.proj_out.bias']
new['diffusion']['final.groupnorm.weight'] = old['model.diffusion_model.out.0.weight']
new['diffusion']['final.groupnorm.bias'] = old['model.diffusion_model.out.0.bias']
new['diffusion']['final.conv.weight'] = old['model.diffusion_model.out.2.weight']
new['diffusion']['final.conv.bias'] = old['model.diffusion_model.out.2.bias']
new['encoder']['0.weight'] = old['first_stage_model.encoder.conv_in.weight']
new['encoder']['0.bias'] = old['first_stage_model.encoder.conv_in.bias']
new['encoder']['1.groupnorm_1.weight'] = old['first_stage_model.encoder.down.0.block.0.norm1.weight']
new['encoder']['1.groupnorm_1.bias'] = old['first_stage_model.encoder.down.0.block.0.norm1.bias']
new['encoder']['1.conv_1.weight'] = old['first_stage_model.encoder.down.0.block.0.conv1.weight']
new['encoder']['1.conv_1.bias'] = old['first_stage_model.encoder.down.0.block.0.conv1.bias']
new['encoder']['1.groupnorm_2.weight'] = old['first_stage_model.encoder.down.0.block.0.norm2.weight']
new['encoder']['1.groupnorm_2.bias'] = old['first_stage_model.encoder.down.0.block.0.norm2.bias']
new['encoder']['1.conv_2.weight'] = old['first_stage_model.encoder.down.0.block.0.conv2.weight']
new['encoder']['1.conv_2.bias'] = old['first_stage_model.encoder.down.0.block.0.conv2.bias']
new['encoder']['2.groupnorm_1.weight'] = old['first_stage_model.encoder.down.0.block.1.norm1.weight']
new['encoder']['2.groupnorm_1.bias'] = old['first_stage_model.encoder.down.0.block.1.norm1.bias']
new['encoder']['2.conv_1.weight'] = old['first_stage_model.encoder.down.0.block.1.conv1.weight']
new['encoder']['2.conv_1.bias'] = old['first_stage_model.encoder.down.0.block.1.conv1.bias']
new['encoder']['2.groupnorm_2.weight'] = old['first_stage_model.encoder.down.0.block.1.norm2.weight']
new['encoder']['2.groupnorm_2.bias'] = old['first_stage_model.encoder.down.0.block.1.norm2.bias']
new['encoder']['2.conv_2.weight'] = old['first_stage_model.encoder.down.0.block.1.conv2.weight']
new['encoder']['2.conv_2.bias'] = old['first_stage_model.encoder.down.0.block.1.conv2.bias']
new['encoder']['3.weight'] = old['first_stage_model.encoder.down.0.downsample.conv.weight']
new['encoder']['3.bias'] = old['first_stage_model.encoder.down.0.downsample.conv.bias']
new['encoder']['4.groupnorm_1.weight'] = old['first_stage_model.encoder.down.1.block.0.norm1.weight']
new['encoder']['4.groupnorm_1.bias'] = old['first_stage_model.encoder.down.1.block.0.norm1.bias']
new['encoder']['4.conv_1.weight'] = old['first_stage_model.encoder.down.1.block.0.conv1.weight']
new['encoder']['4.conv_1.bias'] = old['first_stage_model.encoder.down.1.block.0.conv1.bias']
new['encoder']['4.groupnorm_2.weight'] = old['first_stage_model.encoder.down.1.block.0.norm2.weight']
new['encoder']['4.groupnorm_2.bias'] = old['first_stage_model.encoder.down.1.block.0.norm2.bias']
new['encoder']['4.conv_2.weight'] = old['first_stage_model.encoder.down.1.block.0.conv2.weight']
new['encoder']['4.conv_2.bias'] = old['first_stage_model.encoder.down.1.block.0.conv2.bias']
new['encoder']['4.residual_layer.weight'] = old['first_stage_model.encoder.down.1.block.0.nin_shortcut.weight']
new['encoder']['4.residual_layer.bias'] = old['first_stage_model.encoder.down.1.block.0.nin_shortcut.bias']
new['encoder']['5.groupnorm_1.weight'] = old['first_stage_model.encoder.down.1.block.1.norm1.weight']
new['encoder']['5.groupnorm_1.bias'] = old['first_stage_model.encoder.down.1.block.1.norm1.bias']
new['encoder']['5.conv_1.weight'] = old['first_stage_model.encoder.down.1.block.1.conv1.weight']
new['encoder']['5.conv_1.bias'] = old['first_stage_model.encoder.down.1.block.1.conv1.bias']
new['encoder']['5.groupnorm_2.weight'] = old['first_stage_model.encoder.down.1.block.1.norm2.weight']
new['encoder']['5.groupnorm_2.bias'] = old['first_stage_model.encoder.down.1.block.1.norm2.bias']
new['encoder']['5.conv_2.weight'] = old['first_stage_model.encoder.down.1.block.1.conv2.weight']
new['encoder']['5.conv_2.bias'] = old['first_stage_model.encoder.down.1.block.1.conv2.bias']
new['encoder']['6.weight'] = old['first_stage_model.encoder.down.1.downsample.conv.weight']
new['encoder']['6.bias'] = old['first_stage_model.encoder.down.1.downsample.conv.bias']
new['encoder']['7.groupnorm_1.weight'] = old['first_stage_model.encoder.down.2.block.0.norm1.weight']
new['encoder']['7.groupnorm_1.bias'] = old['first_stage_model.encoder.down.2.block.0.norm1.bias']
new['encoder']['7.conv_1.weight'] = old['first_stage_model.encoder.down.2.block.0.conv1.weight']
new['encoder']['7.conv_1.bias'] = old['first_stage_model.encoder.down.2.block.0.conv1.bias']
new['encoder']['7.groupnorm_2.weight'] = old['first_stage_model.encoder.down.2.block.0.norm2.weight']
new['encoder']['7.groupnorm_2.bias'] = old['first_stage_model.encoder.down.2.block.0.norm2.bias']
new['encoder']['7.conv_2.weight'] = old['first_stage_model.encoder.down.2.block.0.conv2.weight']
new['encoder']['7.conv_2.bias'] = old['first_stage_model.encoder.down.2.block.0.conv2.bias']
new['encoder']['7.residual_layer.weight'] = old['first_stage_model.encoder.down.2.block.0.nin_shortcut.weight']
new['encoder']['7.residual_layer.bias'] = old['first_stage_model.encoder.down.2.block.0.nin_shortcut.bias']
new['encoder']['8.groupnorm_1.weight'] = old['first_stage_model.encoder.down.2.block.1.norm1.weight']
new['encoder']['8.groupnorm_1.bias'] = old['first_stage_model.encoder.down.2.block.1.norm1.bias']
new['encoder']['8.conv_1.weight'] = old['first_stage_model.encoder.down.2.block.1.conv1.weight']
new['encoder']['8.conv_1.bias'] = old['first_stage_model.encoder.down.2.block.1.conv1.bias']
new['encoder']['8.groupnorm_2.weight'] = old['first_stage_model.encoder.down.2.block.1.norm2.weight']
new['encoder']['8.groupnorm_2.bias'] = old['first_stage_model.encoder.down.2.block.1.norm2.bias']
new['encoder']['8.conv_2.weight'] = old['first_stage_model.encoder.down.2.block.1.conv2.weight']
new['encoder']['8.conv_2.bias'] = old['first_stage_model.encoder.down.2.block.1.conv2.bias']
new['encoder']['9.weight'] = old['first_stage_model.encoder.down.2.downsample.conv.weight']
new['encoder']['9.bias'] = old['first_stage_model.encoder.down.2.downsample.conv.bias']
new['encoder']['10.groupnorm_1.weight'] = old['first_stage_model.encoder.down.3.block.0.norm1.weight']
new['encoder']['10.groupnorm_1.bias'] = old['first_stage_model.encoder.down.3.block.0.norm1.bias']
new['encoder']['10.conv_1.weight'] = old['first_stage_model.encoder.down.3.block.0.conv1.weight']
new['encoder']['10.conv_1.bias'] = old['first_stage_model.encoder.down.3.block.0.conv1.bias']
new['encoder']['10.groupnorm_2.weight'] = old['first_stage_model.encoder.down.3.block.0.norm2.weight']
new['encoder']['10.groupnorm_2.bias'] = old['first_stage_model.encoder.down.3.block.0.norm2.bias']
new['encoder']['10.conv_2.weight'] = old['first_stage_model.encoder.down.3.block.0.conv2.weight']
new['encoder']['10.conv_2.bias'] = old['first_stage_model.encoder.down.3.block.0.conv2.bias']
new['encoder']['11.groupnorm_1.weight'] = old['first_stage_model.encoder.down.3.block.1.norm1.weight']
new['encoder']['11.groupnorm_1.bias'] = old['first_stage_model.encoder.down.3.block.1.norm1.bias']
new['encoder']['11.conv_1.weight'] = old['first_stage_model.encoder.down.3.block.1.conv1.weight']
new['encoder']['11.conv_1.bias'] = old['first_stage_model.encoder.down.3.block.1.conv1.bias']
new['encoder']['11.groupnorm_2.weight'] = old['first_stage_model.encoder.down.3.block.1.norm2.weight']
new['encoder']['11.groupnorm_2.bias'] = old['first_stage_model.encoder.down.3.block.1.norm2.bias']
new['encoder']['11.conv_2.weight'] = old['first_stage_model.encoder.down.3.block.1.conv2.weight']
new['encoder']['11.conv_2.bias'] = old['first_stage_model.encoder.down.3.block.1.conv2.bias']
new['encoder']['12.groupnorm_1.weight'] = old['first_stage_model.encoder.mid.block_1.norm1.weight']
new['encoder']['12.groupnorm_1.bias'] = old['first_stage_model.encoder.mid.block_1.norm1.bias']
new['encoder']['12.conv_1.weight'] = old['first_stage_model.encoder.mid.block_1.conv1.weight']
new['encoder']['12.conv_1.bias'] = old['first_stage_model.encoder.mid.block_1.conv1.bias']
new['encoder']['12.groupnorm_2.weight'] = old['first_stage_model.encoder.mid.block_1.norm2.weight']
new['encoder']['12.groupnorm_2.bias'] = old['first_stage_model.encoder.mid.block_1.norm2.bias']
new['encoder']['12.conv_2.weight'] = old['first_stage_model.encoder.mid.block_1.conv2.weight']
new['encoder']['12.conv_2.bias'] = old['first_stage_model.encoder.mid.block_1.conv2.bias']
new['encoder']['13.groupnorm.weight'] = old['first_stage_model.encoder.mid.attn_1.norm.weight']
new['encoder']['13.groupnorm.bias'] = old['first_stage_model.encoder.mid.attn_1.norm.bias']
new['encoder']['13.attention.out_proj.bias'] = old['first_stage_model.encoder.mid.attn_1.proj_out.bias']
new['encoder']['14.groupnorm_1.weight'] = old['first_stage_model.encoder.mid.block_2.norm1.weight']
new['encoder']['14.groupnorm_1.bias'] = old['first_stage_model.encoder.mid.block_2.norm1.bias']
new['encoder']['14.conv_1.weight'] = old['first_stage_model.encoder.mid.block_2.conv1.weight']
new['encoder']['14.conv_1.bias'] = old['first_stage_model.encoder.mid.block_2.conv1.bias']
new['encoder']['14.groupnorm_2.weight'] = old['first_stage_model.encoder.mid.block_2.norm2.weight']
new['encoder']['14.groupnorm_2.bias'] = old['first_stage_model.encoder.mid.block_2.norm2.bias']
new['encoder']['14.conv_2.weight'] = old['first_stage_model.encoder.mid.block_2.conv2.weight']
new['encoder']['14.conv_2.bias'] = old['first_stage_model.encoder.mid.block_2.conv2.bias']
new['encoder']['15.weight'] = old['first_stage_model.encoder.norm_out.weight']
new['encoder']['15.bias'] = old['first_stage_model.encoder.norm_out.bias']
new['encoder']['17.weight'] = old['first_stage_model.encoder.conv_out.weight']
new['encoder']['17.bias'] = old['first_stage_model.encoder.conv_out.bias']
new['decoder']['1.weight'] = old['first_stage_model.decoder.conv_in.weight']
new['decoder']['1.bias'] = old['first_stage_model.decoder.conv_in.bias']
new['decoder']['2.groupnorm_1.weight'] = old['first_stage_model.decoder.mid.block_1.norm1.weight']
new['decoder']['2.groupnorm_1.bias'] = old['first_stage_model.decoder.mid.block_1.norm1.bias']
new['decoder']['2.conv_1.weight'] = old['first_stage_model.decoder.mid.block_1.conv1.weight']
new['decoder']['2.conv_1.bias'] = old['first_stage_model.decoder.mid.block_1.conv1.bias']
new['decoder']['2.groupnorm_2.weight'] = old['first_stage_model.decoder.mid.block_1.norm2.weight']
new['decoder']['2.groupnorm_2.bias'] = old['first_stage_model.decoder.mid.block_1.norm2.bias']
new['decoder']['2.conv_2.weight'] = old['first_stage_model.decoder.mid.block_1.conv2.weight']
new['decoder']['2.conv_2.bias'] = old['first_stage_model.decoder.mid.block_1.conv2.bias']
new['decoder']['3.groupnorm.weight'] = old['first_stage_model.decoder.mid.attn_1.norm.weight']
new['decoder']['3.groupnorm.bias'] = old['first_stage_model.decoder.mid.attn_1.norm.bias']
new['decoder']['3.attention.out_proj.bias'] = old['first_stage_model.decoder.mid.attn_1.proj_out.bias']
new['decoder']['4.groupnorm_1.weight'] = old['first_stage_model.decoder.mid.block_2.norm1.weight']
new['decoder']['4.groupnorm_1.bias'] = old['first_stage_model.decoder.mid.block_2.norm1.bias']
new['decoder']['4.conv_1.weight'] = old['first_stage_model.decoder.mid.block_2.conv1.weight']
new['decoder']['4.conv_1.bias'] = old['first_stage_model.decoder.mid.block_2.conv1.bias']
new['decoder']['4.groupnorm_2.weight'] = old['first_stage_model.decoder.mid.block_2.norm2.weight']
new['decoder']['4.groupnorm_2.bias'] = old['first_stage_model.decoder.mid.block_2.norm2.bias']
new['decoder']['4.conv_2.weight'] = old['first_stage_model.decoder.mid.block_2.conv2.weight']
new['decoder']['4.conv_2.bias'] = old['first_stage_model.decoder.mid.block_2.conv2.bias']
new['decoder']['20.groupnorm_1.weight'] = old['first_stage_model.decoder.up.0.block.0.norm1.weight']
new['decoder']['20.groupnorm_1.bias'] = old['first_stage_model.decoder.up.0.block.0.norm1.bias']
new['decoder']['20.conv_1.weight'] = old['first_stage_model.decoder.up.0.block.0.conv1.weight']
new['decoder']['20.conv_1.bias'] = old['first_stage_model.decoder.up.0.block.0.conv1.bias']
new['decoder']['20.groupnorm_2.weight'] = old['first_stage_model.decoder.up.0.block.0.norm2.weight']
new['decoder']['20.groupnorm_2.bias'] = old['first_stage_model.decoder.up.0.block.0.norm2.bias']
new['decoder']['20.conv_2.weight'] = old['first_stage_model.decoder.up.0.block.0.conv2.weight']
new['decoder']['20.conv_2.bias'] = old['first_stage_model.decoder.up.0.block.0.conv2.bias']
new['decoder']['20.residual_layer.weight'] = old['first_stage_model.decoder.up.0.block.0.nin_shortcut.weight']
new['decoder']['20.residual_layer.bias'] = old['first_stage_model.decoder.up.0.block.0.nin_shortcut.bias']
new['decoder']['21.groupnorm_1.weight'] = old['first_stage_model.decoder.up.0.block.1.norm1.weight']
new['decoder']['21.groupnorm_1.bias'] = old['first_stage_model.decoder.up.0.block.1.norm1.bias']
new['decoder']['21.conv_1.weight'] = old['first_stage_model.decoder.up.0.block.1.conv1.weight']
new['decoder']['21.conv_1.bias'] = old['first_stage_model.decoder.up.0.block.1.conv1.bias']
new['decoder']['21.groupnorm_2.weight'] = old['first_stage_model.decoder.up.0.block.1.norm2.weight']
new['decoder']['21.groupnorm_2.bias'] = old['first_stage_model.decoder.up.0.block.1.norm2.bias']
new['decoder']['21.conv_2.weight'] = old['first_stage_model.decoder.up.0.block.1.conv2.weight']
new['decoder']['21.conv_2.bias'] = old['first_stage_model.decoder.up.0.block.1.conv2.bias']
new['decoder']['22.groupnorm_1.weight'] = old['first_stage_model.decoder.up.0.block.2.norm1.weight']
new['decoder']['22.groupnorm_1.bias'] = old['first_stage_model.decoder.up.0.block.2.norm1.bias']
new['decoder']['22.conv_1.weight'] = old['first_stage_model.decoder.up.0.block.2.conv1.weight']
new['decoder']['22.conv_1.bias'] = old['first_stage_model.decoder.up.0.block.2.conv1.bias']
new['decoder']['22.groupnorm_2.weight'] = old['first_stage_model.decoder.up.0.block.2.norm2.weight']
new['decoder']['22.groupnorm_2.bias'] = old['first_stage_model.decoder.up.0.block.2.norm2.bias']
new['decoder']['22.conv_2.weight'] = old['first_stage_model.decoder.up.0.block.2.conv2.weight']
new['decoder']['22.conv_2.bias'] = old['first_stage_model.decoder.up.0.block.2.conv2.bias']
new['decoder']['15.groupnorm_1.weight'] = old['first_stage_model.decoder.up.1.block.0.norm1.weight']
new['decoder']['15.groupnorm_1.bias'] = old['first_stage_model.decoder.up.1.block.0.norm1.bias']
new['decoder']['15.conv_1.weight'] = old['first_stage_model.decoder.up.1.block.0.conv1.weight']
new['decoder']['15.conv_1.bias'] = old['first_stage_model.decoder.up.1.block.0.conv1.bias']
new['decoder']['15.groupnorm_2.weight'] = old['first_stage_model.decoder.up.1.block.0.norm2.weight']
new['decoder']['15.groupnorm_2.bias'] = old['first_stage_model.decoder.up.1.block.0.norm2.bias']
new['decoder']['15.conv_2.weight'] = old['first_stage_model.decoder.up.1.block.0.conv2.weight']
new['decoder']['15.conv_2.bias'] = old['first_stage_model.decoder.up.1.block.0.conv2.bias']
new['decoder']['15.residual_layer.weight'] = old['first_stage_model.decoder.up.1.block.0.nin_shortcut.weight']
new['decoder']['15.residual_layer.bias'] = old['first_stage_model.decoder.up.1.block.0.nin_shortcut.bias']
new['decoder']['16.groupnorm_1.weight'] = old['first_stage_model.decoder.up.1.block.1.norm1.weight']
new['decoder']['16.groupnorm_1.bias'] = old['first_stage_model.decoder.up.1.block.1.norm1.bias']
new['decoder']['16.conv_1.weight'] = old['first_stage_model.decoder.up.1.block.1.conv1.weight']
new['decoder']['16.conv_1.bias'] = old['first_stage_model.decoder.up.1.block.1.conv1.bias']
new['decoder']['16.groupnorm_2.weight'] = old['first_stage_model.decoder.up.1.block.1.norm2.weight']
new['decoder']['16.groupnorm_2.bias'] = old['first_stage_model.decoder.up.1.block.1.norm2.bias']
new['decoder']['16.conv_2.weight'] = old['first_stage_model.decoder.up.1.block.1.conv2.weight']
new['decoder']['16.conv_2.bias'] = old['first_stage_model.decoder.up.1.block.1.conv2.bias']
new['decoder']['17.groupnorm_1.weight'] = old['first_stage_model.decoder.up.1.block.2.norm1.weight']
new['decoder']['17.groupnorm_1.bias'] = old['first_stage_model.decoder.up.1.block.2.norm1.bias']
new['decoder']['17.conv_1.weight'] = old['first_stage_model.decoder.up.1.block.2.conv1.weight']
new['decoder']['17.conv_1.bias'] = old['first_stage_model.decoder.up.1.block.2.conv1.bias']
new['decoder']['17.groupnorm_2.weight'] = old['first_stage_model.decoder.up.1.block.2.norm2.weight']
new['decoder']['17.groupnorm_2.bias'] = old['first_stage_model.decoder.up.1.block.2.norm2.bias']
new['decoder']['17.conv_2.weight'] = old['first_stage_model.decoder.up.1.block.2.conv2.weight']
new['decoder']['17.conv_2.bias'] = old['first_stage_model.decoder.up.1.block.2.conv2.bias']
new['decoder']['19.weight'] = old['first_stage_model.decoder.up.1.upsample.conv.weight']
new['decoder']['19.bias'] = old['first_stage_model.decoder.up.1.upsample.conv.bias']
new['decoder']['10.groupnorm_1.weight'] = old['first_stage_model.decoder.up.2.block.0.norm1.weight']
new['decoder']['10.groupnorm_1.bias'] = old['first_stage_model.decoder.up.2.block.0.norm1.bias']
new['decoder']['10.conv_1.weight'] = old['first_stage_model.decoder.up.2.block.0.conv1.weight']
new['decoder']['10.conv_1.bias'] = old['first_stage_model.decoder.up.2.block.0.conv1.bias']
new['decoder']['10.groupnorm_2.weight'] = old['first_stage_model.decoder.up.2.block.0.norm2.weight']
new['decoder']['10.groupnorm_2.bias'] = old['first_stage_model.decoder.up.2.block.0.norm2.bias']
new['decoder']['10.conv_2.weight'] = old['first_stage_model.decoder.up.2.block.0.conv2.weight']
new['decoder']['10.conv_2.bias'] = old['first_stage_model.decoder.up.2.block.0.conv2.bias']
new['decoder']['11.groupnorm_1.weight'] = old['first_stage_model.decoder.up.2.block.1.norm1.weight']
new['decoder']['11.groupnorm_1.bias'] = old['first_stage_model.decoder.up.2.block.1.norm1.bias']
new['decoder']['11.conv_1.weight'] = old['first_stage_model.decoder.up.2.block.1.conv1.weight']
new['decoder']['11.conv_1.bias'] = old['first_stage_model.decoder.up.2.block.1.conv1.bias']
new['decoder']['11.groupnorm_2.weight'] = old['first_stage_model.decoder.up.2.block.1.norm2.weight']
new['decoder']['11.groupnorm_2.bias'] = old['first_stage_model.decoder.up.2.block.1.norm2.bias']
new['decoder']['11.conv_2.weight'] = old['first_stage_model.decoder.up.2.block.1.conv2.weight']
new['decoder']['11.conv_2.bias'] = old['first_stage_model.decoder.up.2.block.1.conv2.bias']
new['decoder']['12.groupnorm_1.weight'] = old['first_stage_model.decoder.up.2.block.2.norm1.weight']
new['decoder']['12.groupnorm_1.bias'] = old['first_stage_model.decoder.up.2.block.2.norm1.bias']
new['decoder']['12.conv_1.weight'] = old['first_stage_model.decoder.up.2.block.2.conv1.weight']
new['decoder']['12.conv_1.bias'] = old['first_stage_model.decoder.up.2.block.2.conv1.bias']
new['decoder']['12.groupnorm_2.weight'] = old['first_stage_model.decoder.up.2.block.2.norm2.weight']
new['decoder']['12.groupnorm_2.bias'] = old['first_stage_model.decoder.up.2.block.2.norm2.bias']
new['decoder']['12.conv_2.weight'] = old['first_stage_model.decoder.up.2.block.2.conv2.weight']
new['decoder']['12.conv_2.bias'] = old['first_stage_model.decoder.up.2.block.2.conv2.bias']
new['decoder']['14.weight'] = old['first_stage_model.decoder.up.2.upsample.conv.weight']
new['decoder']['14.bias'] = old['first_stage_model.decoder.up.2.upsample.conv.bias']
new['decoder']['5.groupnorm_1.weight'] = old['first_stage_model.decoder.up.3.block.0.norm1.weight']
new['decoder']['5.groupnorm_1.bias'] = old['first_stage_model.decoder.up.3.block.0.norm1.bias']
new['decoder']['5.conv_1.weight'] = old['first_stage_model.decoder.up.3.block.0.conv1.weight']
new['decoder']['5.conv_1.bias'] = old['first_stage_model.decoder.up.3.block.0.conv1.bias']
new['decoder']['5.groupnorm_2.weight'] = old['first_stage_model.decoder.up.3.block.0.norm2.weight']
new['decoder']['5.groupnorm_2.bias'] = old['first_stage_model.decoder.up.3.block.0.norm2.bias']
new['decoder']['5.conv_2.weight'] = old['first_stage_model.decoder.up.3.block.0.conv2.weight']
new['decoder']['5.conv_2.bias'] = old['first_stage_model.decoder.up.3.block.0.conv2.bias']
new['decoder']['6.groupnorm_1.weight'] = old['first_stage_model.decoder.up.3.block.1.norm1.weight']
new['decoder']['6.groupnorm_1.bias'] = old['first_stage_model.decoder.up.3.block.1.norm1.bias']
new['decoder']['6.conv_1.weight'] = old['first_stage_model.decoder.up.3.block.1.conv1.weight']
new['decoder']['6.conv_1.bias'] = old['first_stage_model.decoder.up.3.block.1.conv1.bias']
new['decoder']['6.groupnorm_2.weight'] = old['first_stage_model.decoder.up.3.block.1.norm2.weight']
new['decoder']['6.groupnorm_2.bias'] = old['first_stage_model.decoder.up.3.block.1.norm2.bias']
new['decoder']['6.conv_2.weight'] = old['first_stage_model.decoder.up.3.block.1.conv2.weight']
new['decoder']['6.conv_2.bias'] = old['first_stage_model.decoder.up.3.block.1.conv2.bias']
new['decoder']['7.groupnorm_1.weight'] = old['first_stage_model.decoder.up.3.block.2.norm1.weight']
new['decoder']['7.groupnorm_1.bias'] = old['first_stage_model.decoder.up.3.block.2.norm1.bias']
new['decoder']['7.conv_1.weight'] = old['first_stage_model.decoder.up.3.block.2.conv1.weight']
new['decoder']['7.conv_1.bias'] = old['first_stage_model.decoder.up.3.block.2.conv1.bias']
new['decoder']['7.groupnorm_2.weight'] = old['first_stage_model.decoder.up.3.block.2.norm2.weight']
new['decoder']['7.groupnorm_2.bias'] = old['first_stage_model.decoder.up.3.block.2.norm2.bias']
new['decoder']['7.conv_2.weight'] = old['first_stage_model.decoder.up.3.block.2.conv2.weight']
new['decoder']['7.conv_2.bias'] = old['first_stage_model.decoder.up.3.block.2.conv2.bias']
new['decoder']['9.weight'] = old['first_stage_model.decoder.up.3.upsample.conv.weight']
new['decoder']['9.bias'] = old['first_stage_model.decoder.up.3.upsample.conv.bias']
new['decoder']['23.weight'] = old['first_stage_model.decoder.norm_out.weight']
new['decoder']['23.bias'] = old['first_stage_model.decoder.norm_out.bias']
new['decoder']['25.weight'] = old['first_stage_model.decoder.conv_out.weight']
new['decoder']['25.bias'] = old['first_stage_model.decoder.conv_out.bias']
new['encoder']['18.weight'] = old['first_stage_model.quant_conv.weight']
new['encoder']['18.bias'] = old['first_stage_model.quant_conv.bias']
new['decoder']['0.weight'] = old['first_stage_model.post_quant_conv.weight']
new['decoder']['0.bias'] = old['first_stage_model.post_quant_conv.bias']
new['clip']['embedding.token_embedding.weight'] = old['cond_stage_model.transformer.text_model.embeddings.token_embedding.weight']
new['clip']['embedding.position_value'] = old['cond_stage_model.transformer.text_model.embeddings.position_embedding.weight']
new['clip']['layers.0.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.self_attn.out_proj.weight']
new['clip']['layers.0.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.self_attn.out_proj.bias']
new['clip']['layers.0.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.layer_norm1.weight']
new['clip']['layers.0.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.layer_norm1.bias']
new['clip']['layers.0.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.mlp.fc1.weight']
new['clip']['layers.0.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.mlp.fc1.bias']
new['clip']['layers.0.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.mlp.fc2.weight']
new['clip']['layers.0.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.mlp.fc2.bias']
new['clip']['layers.0.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.layer_norm2.weight']
new['clip']['layers.0.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.0.layer_norm2.bias']
new['clip']['layers.1.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.self_attn.out_proj.weight']
new['clip']['layers.1.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.self_attn.out_proj.bias']
new['clip']['layers.1.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.layer_norm1.weight']
new['clip']['layers.1.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.layer_norm1.bias']
new['clip']['layers.1.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.mlp.fc1.weight']
new['clip']['layers.1.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.mlp.fc1.bias']
new['clip']['layers.1.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.mlp.fc2.weight']
new['clip']['layers.1.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.mlp.fc2.bias']
new['clip']['layers.1.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.layer_norm2.weight']
new['clip']['layers.1.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.1.layer_norm2.bias']
new['clip']['layers.2.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.self_attn.out_proj.weight']
new['clip']['layers.2.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.self_attn.out_proj.bias']
new['clip']['layers.2.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.layer_norm1.weight']
new['clip']['layers.2.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.layer_norm1.bias']
new['clip']['layers.2.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.mlp.fc1.weight']
new['clip']['layers.2.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.mlp.fc1.bias']
new['clip']['layers.2.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.mlp.fc2.weight']
new['clip']['layers.2.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.mlp.fc2.bias']
new['clip']['layers.2.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.layer_norm2.weight']
new['clip']['layers.2.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.2.layer_norm2.bias']
new['clip']['layers.3.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.self_attn.out_proj.weight']
new['clip']['layers.3.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.self_attn.out_proj.bias']
new['clip']['layers.3.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.layer_norm1.weight']
new['clip']['layers.3.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.layer_norm1.bias']
new['clip']['layers.3.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.mlp.fc1.weight']
new['clip']['layers.3.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.mlp.fc1.bias']
new['clip']['layers.3.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.mlp.fc2.weight']
new['clip']['layers.3.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.mlp.fc2.bias']
new['clip']['layers.3.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.layer_norm2.weight']
new['clip']['layers.3.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.3.layer_norm2.bias']
new['clip']['layers.4.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.self_attn.out_proj.weight']
new['clip']['layers.4.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.self_attn.out_proj.bias']
new['clip']['layers.4.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.layer_norm1.weight']
new['clip']['layers.4.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.layer_norm1.bias']
new['clip']['layers.4.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.mlp.fc1.weight']
new['clip']['layers.4.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.mlp.fc1.bias']
new['clip']['layers.4.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.mlp.fc2.weight']
new['clip']['layers.4.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.mlp.fc2.bias']
new['clip']['layers.4.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.layer_norm2.weight']
new['clip']['layers.4.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.4.layer_norm2.bias']
new['clip']['layers.5.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.self_attn.out_proj.weight']
new['clip']['layers.5.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.self_attn.out_proj.bias']
new['clip']['layers.5.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.layer_norm1.weight']
new['clip']['layers.5.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.layer_norm1.bias']
new['clip']['layers.5.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.mlp.fc1.weight']
new['clip']['layers.5.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.mlp.fc1.bias']
new['clip']['layers.5.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.mlp.fc2.weight']
new['clip']['layers.5.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.mlp.fc2.bias']
new['clip']['layers.5.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.layer_norm2.weight']
new['clip']['layers.5.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.5.layer_norm2.bias']
new['clip']['layers.6.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.out_proj.weight']
new['clip']['layers.6.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.out_proj.bias']
new['clip']['layers.6.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.layer_norm1.weight']
new['clip']['layers.6.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.layer_norm1.bias']
new['clip']['layers.6.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.mlp.fc1.weight']
new['clip']['layers.6.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.mlp.fc1.bias']
new['clip']['layers.6.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.mlp.fc2.weight']
new['clip']['layers.6.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.mlp.fc2.bias']
new['clip']['layers.6.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.layer_norm2.weight']
new['clip']['layers.6.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.6.layer_norm2.bias']
new['clip']['layers.7.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.out_proj.weight']
new['clip']['layers.7.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.out_proj.bias']
new['clip']['layers.7.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.layer_norm1.weight']
new['clip']['layers.7.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.layer_norm1.bias']
new['clip']['layers.7.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.mlp.fc1.weight']
new['clip']['layers.7.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.mlp.fc1.bias']
new['clip']['layers.7.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.mlp.fc2.weight']
new['clip']['layers.7.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.mlp.fc2.bias']
new['clip']['layers.7.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.layer_norm2.weight']
new['clip']['layers.7.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.7.layer_norm2.bias']
new['clip']['layers.8.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.out_proj.weight']
new['clip']['layers.8.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.out_proj.bias']
new['clip']['layers.8.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.layer_norm1.weight']
new['clip']['layers.8.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.layer_norm1.bias']
new['clip']['layers.8.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.mlp.fc1.weight']
new['clip']['layers.8.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.mlp.fc1.bias']
new['clip']['layers.8.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.mlp.fc2.weight']
new['clip']['layers.8.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.mlp.fc2.bias']
new['clip']['layers.8.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.layer_norm2.weight']
new['clip']['layers.8.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.8.layer_norm2.bias']
new['clip']['layers.9.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.out_proj.weight']
new['clip']['layers.9.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.out_proj.bias']
new['clip']['layers.9.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.layer_norm1.weight']
new['clip']['layers.9.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.layer_norm1.bias']
new['clip']['layers.9.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.mlp.fc1.weight']
new['clip']['layers.9.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.mlp.fc1.bias']
new['clip']['layers.9.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.mlp.fc2.weight']
new['clip']['layers.9.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.mlp.fc2.bias']
new['clip']['layers.9.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.layer_norm2.weight']
new['clip']['layers.9.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.9.layer_norm2.bias']
new['clip']['layers.10.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.self_attn.out_proj.weight']
new['clip']['layers.10.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.self_attn.out_proj.bias']
new['clip']['layers.10.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.layer_norm1.weight']
new['clip']['layers.10.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.layer_norm1.bias']
new['clip']['layers.10.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.mlp.fc1.weight']
new['clip']['layers.10.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.mlp.fc1.bias']
new['clip']['layers.10.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.mlp.fc2.weight']
new['clip']['layers.10.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.mlp.fc2.bias']
new['clip']['layers.10.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.layer_norm2.weight']
new['clip']['layers.10.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.10.layer_norm2.bias']
new['clip']['layers.11.attention.out_proj.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.self_attn.out_proj.weight']
new['clip']['layers.11.attention.out_proj.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.self_attn.out_proj.bias']
new['clip']['layers.11.layernorm_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.layer_norm1.weight']
new['clip']['layers.11.layernorm_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.layer_norm1.bias']
new['clip']['layers.11.linear_1.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.mlp.fc1.weight']
new['clip']['layers.11.linear_1.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.mlp.fc1.bias']
new['clip']['layers.11.linear_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.mlp.fc2.weight']
new['clip']['layers.11.linear_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.mlp.fc2.bias']
new['clip']['layers.11.layernorm_2.weight'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.layer_norm2.weight']
new['clip']['layers.11.layernorm_2.bias'] = old['cond_stage_model.transformer.text_model.encoder.layers.11.layer_norm2.bias']
new['clip']['layernorm.weight'] = old['cond_stage_model.transformer.text_model.final_layer_norm.weight']
new['clip']['layernorm.bias'] = old['cond_stage_model.transformer.text_model.final_layer_norm.bias']
new['diffusion']['unet.encoders.1.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.input_blocks.1.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.encoders.2.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.input_blocks.2.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.encoders.4.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.input_blocks.4.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.encoders.5.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.input_blocks.5.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.encoders.7.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.input_blocks.7.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.encoders.8.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.input_blocks.8.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.bottleneck.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.middle_block.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.decoders.3.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.output_blocks.3.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.decoders.4.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.output_blocks.4.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.decoders.5.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.output_blocks.5.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.decoders.6.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.output_blocks.6.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.decoders.7.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.output_blocks.7.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.decoders.8.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.output_blocks.8.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.decoders.9.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.output_blocks.9.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.decoders.10.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.output_blocks.10.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['diffusion']['unet.decoders.11.1.attention_1.in_proj.weight'] = torch.cat((old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn1.to_q.weight'], old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn1.to_k.weight'], old['model.diffusion_model.output_blocks.11.1.transformer_blocks.0.attn1.to_v.weight']), 0)
new['encoder']['13.attention.in_proj.weight'] = torch.cat((old['first_stage_model.encoder.mid.attn_1.q.weight'], old['first_stage_model.encoder.mid.attn_1.k.weight'], old['first_stage_model.encoder.mid.attn_1.v.weight']), 0).reshape((1536, 512))
new['encoder']['13.attention.in_proj.bias'] = torch.cat((old['first_stage_model.encoder.mid.attn_1.q.bias'], old['first_stage_model.encoder.mid.attn_1.k.bias'], old['first_stage_model.encoder.mid.attn_1.v.bias']), 0)
new['encoder']['13.attention.out_proj.weight'] = old['first_stage_model.encoder.mid.attn_1.proj_out.weight'].reshape((512, 512))
new['decoder']['3.attention.in_proj.weight'] = torch.cat((old['first_stage_model.decoder.mid.attn_1.q.weight'], old['first_stage_model.decoder.mid.attn_1.k.weight'], old['first_stage_model.decoder.mid.attn_1.v.weight']), 0).reshape((1536, 512))
new['decoder']['3.attention.in_proj.bias'] = torch.cat((old['first_stage_model.decoder.mid.attn_1.q.bias'], old['first_stage_model.decoder.mid.attn_1.k.bias'], old['first_stage_model.decoder.mid.attn_1.v.bias']), 0)
new['decoder']['3.attention.out_proj.weight'] = old['first_stage_model.decoder.mid.attn_1.proj_out.weight'].reshape((512, 512))
new['clip']['layers.0.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.0.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.0.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.0.self_attn.v_proj.weight']), 0)
new['clip']['layers.0.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.0.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.0.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.0.self_attn.v_proj.bias']), 0)
new['clip']['layers.1.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.1.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.1.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.1.self_attn.v_proj.weight']), 0)
new['clip']['layers.1.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.1.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.1.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.1.self_attn.v_proj.bias']), 0)
new['clip']['layers.2.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.2.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.2.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.2.self_attn.v_proj.weight']), 0)
new['clip']['layers.2.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.2.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.2.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.2.self_attn.v_proj.bias']), 0)
new['clip']['layers.3.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.3.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.3.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.3.self_attn.v_proj.weight']), 0)
new['clip']['layers.3.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.3.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.3.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.3.self_attn.v_proj.bias']), 0)
new['clip']['layers.4.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.4.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.4.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.4.self_attn.v_proj.weight']), 0)
new['clip']['layers.4.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.4.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.4.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.4.self_attn.v_proj.bias']), 0)
new['clip']['layers.5.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.5.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.5.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.5.self_attn.v_proj.weight']), 0)
new['clip']['layers.5.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.5.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.5.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.5.self_attn.v_proj.bias']), 0)
new['clip']['layers.6.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.v_proj.weight']), 0)
new['clip']['layers.6.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.6.self_attn.v_proj.bias']), 0)
new['clip']['layers.7.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.v_proj.weight']), 0)
new['clip']['layers.7.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.7.self_attn.v_proj.bias']), 0)
new['clip']['layers.8.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.v_proj.weight']), 0)
new['clip']['layers.8.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.8.self_attn.v_proj.bias']), 0)
new['clip']['layers.9.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.v_proj.weight']), 0)
new['clip']['layers.9.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.9.self_attn.v_proj.bias']), 0)
new['clip']['layers.10.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.10.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.10.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.10.self_attn.v_proj.weight']), 0)
new['clip']['layers.10.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.10.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.10.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.10.self_attn.v_proj.bias']), 0)
new['clip']['layers.11.attention.in_proj.weight'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.11.self_attn.q_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.11.self_attn.k_proj.weight'], old['cond_stage_model.transformer.text_model.encoder.layers.11.self_attn.v_proj.weight']), 0)
new['clip']['layers.11.attention.in_proj.bias'] = torch.cat((old['cond_stage_model.transformer.text_model.encoder.layers.11.self_attn.q_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.11.self_attn.k_proj.bias'], old['cond_stage_model.transformer.text_model.encoder.layers.11.self_attn.v_proj.bias']), 0)

torch.save(new['diffusion'], "/content/stable-diffusion-pytorch/data/ckpt/diffusion.pt")
torch.save(new['encoder'], "/content/stable-diffusion-pytorch/data/ckpt/encoder.pt")
torch.save(new['decoder'], "/content/stable-diffusion-pytorch/data/ckpt/decoder.pt")
torch.save(new['clip'], "/content/stable-diffusion-pytorch/data/ckpt/clip.pt")

del old, new
with torch.no_grad():
  torch.cuda.empty_cache()
gc.collect()

# %cd /content/stable-diffusion-pytorch
from stable_diffusion_pytorch import model_loader
models = model_loader.preload_models('cpu')

# %%
import os, gc, requests, json, piexif, torch
from diffusers import StableDiffusionPipeline
from PIL.PngImagePlugin import PngInfo
from fold_to_ascii import fold
from stable_diffusion_pytorch import pipeline

metadata = PngInfo()

def closestNumber(n, m):
    q = int(n / m)
    n1 = m * q
    if (n * m) > 0:
        n2 = m * (q + 1)
    else:
        n2 = m * (q - 1)
    if abs(n - n1) < abs(n - n2):
        return n1
    return n2

root_folder = 'images'

if os.path.exists(f"{root_folder}") == False:
    os.mkdir(f"{root_folder}")
image_folder = max([int(f) for f in os.listdir(f"{root_folder}")], default=0)
if os.path.exists(f"{root_folder}/{image_folder:04}") == False:
    os.mkdir(f"{root_folder}/{image_folder:04}")
name = max([int(f[: f.index(".")]) for f in os.listdir(f"{root_folder}/{image_folder:04}")], default=0)

def generate(discord_token, discord_channel_id, discord_user, by, num_inference_steps, guidance_scale, sampler, width, height, prompt, negative_prompt, suffix, image_folder, name):
    width = closestNumber(width, 8)
    height = closestNumber(height, 8)
    metadata.add_text("Prompt", f"{prompt}")
    metadata.add_text("by", f"{by}")
    gc.collect()
    real_seed = torch.cuda.initial_seed()

    # https://github.com/kjsman/stable-diffusion-pytorch/blob/main/demo.ipynb modified thanks to @kjsman ❤
    image = pipeline.generate(prompts=prompt, uncond_prompts=negative_prompt,
                    input_images=None, strength=0.8,
                    do_cfg=True, cfg_scale=guidance_scale,
                    height=height, width=width, sampler="k_lms",
                    n_inference_steps=num_inference_steps, seed=None,
                    models=models, device='cuda', idle_device='cpu')[0]

    if(suffix == 'png'):
      image.save(f"{root_folder}/{image_folder:04}/{name:04}.{suffix}", pnginfo=metadata)
    else:
      zeroth_ifd = {piexif.ImageIFD.ImageDescription: f"{fold(prompt)}", piexif.ImageIFD.Make: f"{fold(by)}", piexif.ImageIFD.Model: f"{ckpt}", piexif.ImageIFD.Copyright: f"Attribution 4.0 International (CC BY 4.0)"}
      exif_dict = {"0th": zeroth_ifd}
      exif_bytes = piexif.dump(exif_dict)
      image.save(f"{root_folder}/{image_folder:04}/{name:04}.{suffix}", "JPEG", quality=70, exif=exif_bytes)
    files = {f"{image_folder:04}_{name:04}.{suffix}": open(f"{root_folder}/{image_folder:04}/{name:04}.{suffix}", "rb").read()}
    payload = {"content": f"{prompt}\nSteps: {num_inference_steps}, Sampler: {sampler}, CFG scale: {guidance_scale}, Seed: {real_seed}, Size: {width}x{height}, Model folder: {ckpt} - {discord_user}"}
    requests.post(f"https://discord.com/api/v9/channels/{discord_channel_id}/messages", data=payload, headers={"authorization": f"Bot {discord_token}"}, files=files)
    os.remove(f"{root_folder}/{image_folder:04}/{name:04}.{suffix}")

# %%
with open("template.json", "r") as file:
    prompts = file.readlines()
for prompt in prompts:
    d = json.loads(prompt)
    name += 1
    generate(d["discord_token"], d["discord_channel_id"], "camenduru", d["by"], d["num_inference_steps"], d["guidance_scale"], d["sampler"], d["width"], d["height"], d["prompt"], d["negative_prompt"], d["suffix"], image_folder, name)
